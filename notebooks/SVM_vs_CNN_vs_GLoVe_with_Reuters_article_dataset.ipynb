# %% [markdown]
# # **Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
BASE_PATH = "/content/drive/MyDrive/reuters_text_classification"
MODELS_PATH = f"{BASE_PATH}/models"
NOTEBOOKS_PATH = f"{BASE_PATH}/notebooks"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Data download and preprocessing** #

# %% [markdown]
# ***Download and split the data***

# %%
from tensorflow.keras.datasets import reuters
from sklearn.model_selection import train_test_split
import numpy as np

# Load dataset with an 80/20 split between training and testing
(X_train, y_train), (X_test, y_test) = reuters.load_data(test_split=0.2)

# See the first few rows of X_train and y_train to verify the download worked
print(X_train[:3])
print('\n',y_train[:3])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# [list([1, 27595, 28842, 8, 43, 10, 447, 5, 25, 207, 270, 5, 3095, 111, 16, 369, 186, 90, 67, 7, 89, 5, 19, 102, 6, 19, 124, 15, 90, 67, 84, 22, 482, 26, 7, 48, 4, 49, 8, 864, 39, 209, 154, 6, 151, 6, 83, 11, 15, 22, 155, 11, 15, 7, 48, 9, 4579, 1005, 504, 6, 258, 6, 272, 11, 15, 22, 134, 44, 11, 15, 16, 8, 197, 1245, 90, 67, 52, 29, 209, 30, 32, 132, 6, 109, 15, 17, 12])
#  list([1, 3267, 699, 3434, 2295, 56, 16784, 7511, 9, 56, 3906, 1073, 81, 5, 1198, 57, 366, 737, 132, 20, 4093, 7, 19261, 49, 2295, 13415, 1037, 3267, 699, 3434, 8, 7, 10, 241, 16, 855, 129, 231, 783, 5, 4, 587, 2295, 13415, 30625, 775, 7, 48, 34, 191, 44, 35, 1795, 505, 17, 12])
#  list([1, 53, 12, 284, 15, 14, 272, 26, 53, 959, 32, 818, 15, 14, 272, 26, 39, 684, 70, 11, 14, 12, 3886, 18, 180, 183, 187, 70, 11, 14, 102, 32, 11, 29, 53, 44, 704, 15, 14, 19, 758, 15, 53, 959, 47, 1013, 15, 14, 19, 132, 15, 39, 965, 32, 11, 14, 147, 72, 11, 180, 183, 187, 44, 11, 14, 102, 19, 11, 123, 186, 90, 67, 960, 4, 78, 13, 68, 467, 511, 110, 59, 89, 90, 67, 1390, 55, 2678, 92, 617, 80, 1274, 46, 905, 220, 13, 4, 346, 48, 235, 629, 5, 211, 5, 1118, 7, 11733, 81, 5, 187, 11, 15, 9, 1709, 201, 5, 47, 3615, 18, 478, 4514, 5, 1118, 7, 232, 13051, 71, 5, 160, 63, 11, 9, 26503, 81, 5, 102, 59, 11, 17, 12])]
#
#  [3 4 3]

# %% [markdown]
# ***Translate integers to words***

# %%
# Get the word-to-index mapping
word_index = reuters.get_word_index()

# Flip it so it becomes an index-to-word mapping
text_index = {value: key for key, value in word_index.items()}

# Test if it works
print(text_index[27595])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters_word_index.json
# 550378/550378 ━━━━━━━━━━━━━━━━━━━━ 1s 2us/step
# wattie

# %% [markdown]
# ***Vectorize the training dataset***

# %%
# Array will hold the decoded text for X_train
X_train_text = []

# Decode training data from integer into text
for index_word_pair in X_train:
    X_train_word_array = []
    for this_word in index_word_pair:
        current_word = text_index.get(this_word - 3, '?')
        X_train_word_array.append(current_word)
    current_sentence = ' '.join(X_train_word_array)
    X_train_text.append(current_sentence)

# %% [markdown]
# ***Vectorize the testing dataset***

# %%
# Array will hold the decoded text for X_test
X_test_text = []

# Decode test data
for index_word_pair in X_test:
    X_test_word_array = []
    for this_word in index_word_pair:
        current_word = text_index.get(this_word - 3, '?')
        X_test_word_array.append(current_word)
    X_test_sentence = ' '.join(X_test_word_array)
    X_test_text.append(X_test_sentence)

# %% [markdown]
# ***Convert text to TF-IDF vectors for SVM model***

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import TfidfVectorizer as tfidf

# Convert text
vector = tfidf(max_features=None,  # Let min_df/max_df decide
               min_df=5,
               max_df=0.9)
X_train_vector = vector.fit_transform(X_train_text)
X_test_vector = vector.transform(X_test_text)
print(len(vector.vocabulary_))
# Out:
# 9101

# %% [markdown]
# # **Phase 1: SVM model**

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report, accuracy_score

# Choose C=1 as an initial C
svm_model = LinearSVC(C=1,
                      class_weight = 'balanced')
svm_model.fit(X_train_vector, y_train)

# Perform initial predictions and evaluate results
y_pred_svm = svm_model.predict(X_test_vector)
print(f"Accuracy: {accuracy_score(y_test, y_pred_svm)}")
print(f"Classification report:\n{classification_report(y_test, y_pred_svm)}")
# Out:
# Accuracy: 0.8308103294746215
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.76      0.77      0.77       105
#            2       0.77      0.85      0.81        20
#            3       0.95      0.92      0.93       813
#            4       0.87      0.88      0.87       474
#            5       0.33      0.20      0.25         5
#            6       0.81      0.93      0.87        14
#            7       0.75      1.00      0.86         3
#            8       0.66      0.71      0.68        38
#            9       0.80      0.96      0.87        25
#           10       0.82      0.93      0.88        30
#           11       0.70      0.73      0.72        83
#           12       0.50      0.54      0.52        13
#           13       0.67      0.76      0.71        37
#           14       0.29      1.00      0.44         2
#           15       0.67      0.44      0.53         9
#           16       0.77      0.82      0.79        99
#           17       0.71      0.83      0.77        12
#           18       0.74      0.70      0.72        20
#           19       0.80      0.66      0.72       133
#           20       0.58      0.61      0.60        70
#           21       0.56      0.89      0.69        27
#           22       1.00      0.29      0.44         7
#           23       0.67      0.83      0.74        12
#           24       0.58      0.58      0.58        19
#           25       0.88      0.94      0.91        31
#           26       0.88      0.88      0.88         8
#           27       0.67      0.50      0.57         4
#           28       0.44      0.40      0.42        10
#           29       0.50      1.00      0.67         4
#           30       1.00      0.75      0.86        12
#           31       0.82      0.69      0.75        13
#           32       0.91      1.00      0.95        10
#           33       0.80      0.80      0.80         5
#           34       0.80      0.57      0.67         7
#           35       1.00      0.67      0.80         6
#           36       0.46      0.55      0.50        11
#           37       0.50      1.00      0.67         2
#           38       0.67      0.67      0.67         3
#           39       0.40      0.40      0.40         5
#           40       0.60      0.30      0.40        10
#           41       0.71      0.62      0.67         8
#           42       1.00      0.67      0.80         3
#           43       0.67      1.00      0.80         6
#           44       0.57      0.80      0.67         5
#           45       0.50      1.00      0.67         1
#
#     accuracy                           0.83      2246
#    macro avg       0.70      0.73      0.70      2246
# weighted avg       0.84      0.83      0.83      2246

# %% [markdown]
# ***Attempt to improve the model by tuning the hyperparamter C***

# %%
from sklearn.model_selection import cross_val_score

# Test different C values
c_values = [0.01, 0.1, 1.0, 10.0, 100.0]
best_C = None
best_score = 0

# Iterate over the 5 c_values
for test_c in c_values:

    # create a model based on test_c
    svm_model = LinearSVC(C=test_c)  #Linear is best for clean text

    # Score the model on 5-fold cross-validation. Use n_jobs=-1 for speed purposes
    result = cross_val_score(svm_model, X_train_vector, y_train, cv=5, scoring='accuracy', n_jobs=-1)

    # Average the resultant scores
    ave_result = np.mean(result)

    # Print the averaged accuracy and standard deviation
    print(f"C={test_c}: Mean CV Accuracy = {ave_result:.4f} (±{np.std(result):.4f})")

    # Hold the C value based on the best average mean score
    if ave_result > best_score:
        best_score = ave_result
        best_C = test_c

# Print best C
print("\nBest C value:", best_C)
print("Best mean CV accuracy:", best_score)
# Out:
# C=0.01: Mean CV Accuracy = 0.6899 (±0.0064)
# C=0.1: Mean CV Accuracy = 0.8308 (±0.0062)
# C=1.0: Mean CV Accuracy = 0.8408 (±0.0063)
# C=10.0: Mean CV Accuracy = 0.8199 (±0.0060)
# C=100.0: Mean CV Accuracy = 0.8100 (±0.0039)
#
# Best C value: 1.0
# Best mean CV accuracy: 0.8407933043565556

# %% [markdown]
# ***A C-value of 1 had the best accuracy (in my run). Further tuning by setting C-values between 1 and 10, inclusive***

# %%
c_values = range(1, 11)
best_C = None
best_score = 0

# Iterate over the 10 c_values
for test_c in c_values:
    # create a model based on test_c
    svm_model = LinearSVC(C=test_c)

    # Score the model on 5-fold cross-validation. Use n_jobs=-1 for speed purposes
    result = cross_val_score(svm_model, X_train_vector, y_train, cv=5, scoring='accuracy', n_jobs=-1)

    # Average the resultant scores
    ave_result = np.mean(result)

    # Print the averaged accuracy and standard deviation
    print(f"C={test_c}: Mean CV Accuracy = {ave_result:.4f} (±{np.std(result):.4f})")

    # Hold the C value based on the best average mean score
    if ave_result > best_score:
        best_score = ave_result
        best_C = test_c

# Print best C
print("\nBest C value:", best_C)
print("Best mean CV accuracy:", best_score)
# Out:
# C=1: Mean CV Accuracy = 0.8408 (±0.0063)
# C=2: Mean CV Accuracy = 0.8314 (±0.0069)
# C=3: Mean CV Accuracy = 0.8271 (±0.0060)
# C=4: Mean CV Accuracy = 0.8257 (±0.0057)
# C=5: Mean CV Accuracy = 0.8235 (±0.0054)
# C=6: Mean CV Accuracy = 0.8222 (±0.0050)
# C=7: Mean CV Accuracy = 0.8213 (±0.0056)
# C=8: Mean CV Accuracy = 0.8206 (±0.0056)
# C=9: Mean CV Accuracy = 0.8203 (±0.0059)
# C=10: Mean CV Accuracy = 0.8199 (±0.0060)
#
# Best C value: 1
# Best mean CV accuracy: 0.8407933043565556

# %% [markdown]
# ***Fit the model with the best C-value and display the accuracy***

# %%
# Choose C=1 as it was determined to be the best value
svm_model = LinearSVC(C=1,
                      class_weight = 'balanced')
svm_model = svm_model.fit(X_train_vector, y_train)

# Perform predictions and evaluate results
y_pred_svm = svm_model.predict(X_test_vector)
print(f"Accuracy: {accuracy_score(y_test, y_pred_svm):.3f}\n")
print(f"Classification report:\n{classification_report(y_test, y_pred_svm)}")
# Out:
# Accuracy: 0.831
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.76      0.77      0.77       105
#            2       0.77      0.85      0.81        20
#            3       0.95      0.92      0.93       813
#            4       0.87      0.88      0.87       474
#            5       0.33      0.20      0.25         5
#            6       0.81      0.93      0.87        14
#            7       0.75      1.00      0.86         3
#            8       0.66      0.71      0.68        38
#            9       0.80      0.96      0.87        25
#           10       0.82      0.93      0.88        30
#           11       0.70      0.73      0.72        83
#           12       0.50      0.54      0.52        13
#           13       0.67      0.76      0.71        37
#           14       0.29      1.00      0.44         2
#           15       0.67      0.44      0.53         9
#           16       0.77      0.82      0.79        99
#           17       0.71      0.83      0.77        12
#           18       0.74      0.70      0.72        20
#           19       0.80      0.66      0.72       133
#           20       0.58      0.61      0.60        70
#           21       0.56      0.89      0.69        27
#           22       1.00      0.29      0.44         7
#           23       0.67      0.83      0.74        12
#           24       0.58      0.58      0.58        19
#           25       0.88      0.94      0.91        31
#           26       0.88      0.88      0.88         8
#           27       0.67      0.50      0.57         4
#           28       0.44      0.40      0.42        10
#           29       0.50      1.00      0.67         4
#           30       1.00      0.75      0.86        12
#           31       0.82      0.69      0.75        13
#           32       0.91      1.00      0.95        10
#           33       0.80      0.80      0.80         5
#           34       0.80      0.57      0.67         7
#           35       1.00      0.67      0.80         6
#           36       0.46      0.55      0.50        11
#           37       0.50      1.00      0.67         2
#           38       0.67      0.67      0.67         3
#           39       0.40      0.40      0.40         5
#           40       0.60      0.30      0.40        10
#           41       0.71      0.62      0.67         8
#           42       1.00      0.67      0.80         3
#           43       0.67      1.00      0.80         6
#           44       0.57      0.80      0.67         5
#           45       0.50      1.00      0.67         1
#
#     accuracy                           0.83      2246
#    macro avg       0.70      0.73      0.70      2246
# weighted avg       0.84      0.83      0.83      2246

# %% [markdown]
# # **Phase 2: Build the CNN model using raw integer sequences**

# %% [markdown]
# ***This piece will help increase visibility of minor classes without pulling down weighting (much) of major classes***

# %%
def scaled_class_weights(base_dict, scale):
    return {cls: 1.0 + (w - 1.0) * scale for cls, w in base_dict.items()}

# %% [markdown]
# ***Load the data and build the training and test sets***

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
#load
(x_train, y_train), (x_test, y_test) = reuters.load_data(num_words=15000)

#pad sequence
maxlen = 300
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

#number of classes
num_classes = int(np.max(y_train) + 1)

# %% [markdown]
# ***Change the label values to categories by one-hot encoding***

# %%
from tensorflow.keras.utils import to_categorical
#oneHot Encode Labels
y_train_cnn = to_categorical(y_train, num_classes)
y_test_cnn = to_categorical(y_test, num_classes)

# %% [markdown]
# ***Create class weighting dictionary***

# %%
from sklearn.utils.class_weight import compute_class_weight

# y_train is one-hot encoded so convert back to class IDs
y_train_labels = np.argmax(y_train_cnn, axis=1)

# Load the class labels
classes = np.unique(y_train_labels)

# Compute the weights
weights = compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=y_train_labels
)

# Fill the dictionary
class_weight_dict = dict(zip(classes, weights))

# Retrieve and save the weightings.
class_weightings = scaled_class_weights(class_weight_dict, 0.1)

# %% [markdown]
# ***Import libraries and build the model***

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout

#build CNN Model
cnn_model = Sequential([
    Embedding(input_dim=15000, output_dim=128),
    Conv1D(filters=64, kernel_size=5, activation='relu'),
    GlobalMaxPooling1D(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ***Compile the model***

# %%
#complile the CNN model
cnn_model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %% [markdown]
# ***Train and evaluate the model***

# %%
history = cnn_model.fit(
    x_train, y_train_cnn,
    epochs=100, # no early stopping set yet
    batch_size=128,
    validation_split=0.2,
    class_weight=class_weightings
)

# Evaluate the results
test_loss, test_acc = cnn_model.evaluate(x_test, y_test_cnn)
print(f"Test Accuracy: {test_acc:.4f}")

# Save the predictions for later comparisons
y_pred_cnn = cnn_model.predict(x_test)
y_pred_cnn_classes = y_pred_cnn.argmax(axis=1)
y_true_cnn_classes = np.argmax(y_test_cnn, axis=1)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.3910 - loss: 2.7730 - val_accuracy: 0.4986 - val_loss: 1.9869
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5084 - loss: 2.1601 - val_accuracy: 0.5376 - val_loss: 1.7718
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5808 - loss: 1.9217 - val_accuracy: 0.6811 - val_loss: 1.4908
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6626 - loss: 1.6717 - val_accuracy: 0.7051 - val_loss: 1.3182
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6937 - loss: 1.4999 - val_accuracy: 0.7257 - val_loss: 1.2191
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7276 - loss: 1.3560 - val_accuracy: 0.7407 - val_loss: 1.1430
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7563 - loss: 1.2072 - val_accuracy: 0.7507 - val_loss: 1.0925
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7781 - loss: 1.0831 - val_accuracy: 0.7635 - val_loss: 1.0328
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8095 - loss: 0.9530 - val_accuracy: 0.7735 - val_loss: 1.0068
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8309 - loss: 0.8455 - val_accuracy: 0.7824 - val_loss: 0.9834
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8476 - loss: 0.7500 - val_accuracy: 0.7858 - val_loss: 0.9820
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8646 - loss: 0.6660 - val_accuracy: 0.7852 - val_loss: 0.9736
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8792 - loss: 0.5973 - val_accuracy: 0.7919 - val_loss: 0.9711
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8931 - loss: 0.5257 - val_accuracy: 0.7896 - val_loss: 1.0241
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9044 - loss: 0.4687 - val_accuracy: 0.7908 - val_loss: 1.0178
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9101 - loss: 0.4352 - val_accuracy: 0.7863 - val_loss: 1.0460
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9150 - loss: 0.4036 - val_accuracy: 0.7869 - val_loss: 1.0659
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9208 - loss: 0.3692 - val_accuracy: 0.7896 - val_loss: 1.1023
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9261 - loss: 0.3587 - val_accuracy: 0.7824 - val_loss: 1.1317
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9303 - loss: 0.3238 - val_accuracy: 0.7852 - val_loss: 1.1349
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9303 - loss: 0.3035 - val_accuracy: 0.7802 - val_loss: 1.1681
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9350 - loss: 0.2893 - val_accuracy: 0.7807 - val_loss: 1.1807
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9388 - loss: 0.2743 - val_accuracy: 0.7780 - val_loss: 1.2118
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9424 - loss: 0.2585 - val_accuracy: 0.7774 - val_loss: 1.2523
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9393 - loss: 0.2576 - val_accuracy: 0.7791 - val_loss: 1.2665
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9453 - loss: 0.2436 - val_accuracy: 0.7752 - val_loss: 1.2812
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9459 - loss: 0.2327 - val_accuracy: 0.7813 - val_loss: 1.2626
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9452 - loss: 0.2241 - val_accuracy: 0.7785 - val_loss: 1.3284
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9485 - loss: 0.2176 - val_accuracy: 0.7763 - val_loss: 1.3088
# Epoch 30/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9457 - loss: 0.2385 - val_accuracy: 0.7785 - val_loss: 1.3428
# Epoch 31/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9477 - loss: 0.2150 - val_accuracy: 0.7780 - val_loss: 1.3138
# Epoch 32/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9496 - loss: 0.2072 - val_accuracy: 0.7791 - val_loss: 1.3685
# Epoch 33/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9485 - loss: 0.1989 - val_accuracy: 0.7819 - val_loss: 1.3664
# Epoch 34/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9507 - loss: 0.2006 - val_accuracy: 0.7791 - val_loss: 1.3439
# Epoch 35/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9534 - loss: 0.1838 - val_accuracy: 0.7730 - val_loss: 1.3868
# Epoch 36/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9562 - loss: 0.1866 - val_accuracy: 0.7763 - val_loss: 1.4211
# Epoch 37/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9530 - loss: 0.1824 - val_accuracy: 0.7780 - val_loss: 1.4548
# Epoch 38/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9581 - loss: 0.1629 - val_accuracy: 0.7757 - val_loss: 1.4380
# Epoch 39/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9549 - loss: 0.1764 - val_accuracy: 0.7718 - val_loss: 1.4655
# Epoch 40/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9567 - loss: 0.1685 - val_accuracy: 0.7741 - val_loss: 1.4909
# Epoch 41/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9546 - loss: 0.1620 - val_accuracy: 0.7663 - val_loss: 1.5295
# Epoch 42/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9549 - loss: 0.1710 - val_accuracy: 0.7691 - val_loss: 1.5216
# Epoch 43/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9557 - loss: 0.1583 - val_accuracy: 0.7685 - val_loss: 1.5421
# Epoch 44/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9578 - loss: 0.1568 - val_accuracy: 0.7707 - val_loss: 1.5583
# Epoch 45/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9567 - loss: 0.1587 - val_accuracy: 0.7691 - val_loss: 1.5402
# Epoch 46/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9567 - loss: 0.1599 - val_accuracy: 0.7696 - val_loss: 1.5976
# Epoch 47/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9570 - loss: 0.1565 - val_accuracy: 0.7702 - val_loss: 1.6134
# Epoch 48/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9578 - loss: 0.1645 - val_accuracy: 0.7652 - val_loss: 1.5942
# Epoch 49/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9557 - loss: 0.1586 - val_accuracy: 0.7674 - val_loss: 1.6375
# Epoch 50/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9555 - loss: 0.1612 - val_accuracy: 0.7641 - val_loss: 1.6541
# Epoch 51/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9563 - loss: 0.1531 - val_accuracy: 0.7641 - val_loss: 1.6699
# Epoch 52/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9573 - loss: 0.1487 - val_accuracy: 0.7641 - val_loss: 1.6558
# Epoch 53/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9602 - loss: 0.1355 - val_accuracy: 0.7629 - val_loss: 1.6838
# Epoch 54/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9608 - loss: 0.1309 - val_accuracy: 0.7641 - val_loss: 1.7363
# Epoch 55/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9585 - loss: 0.1438 - val_accuracy: 0.7574 - val_loss: 1.7102
# Epoch 56/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9578 - loss: 0.1343 - val_accuracy: 0.7602 - val_loss: 1.7026
# Epoch 57/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9605 - loss: 0.1346 - val_accuracy: 0.7635 - val_loss: 1.7534
# Epoch 58/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9578 - loss: 0.1403 - val_accuracy: 0.7641 - val_loss: 1.7447
# Epoch 59/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9599 - loss: 0.1373 - val_accuracy: 0.7674 - val_loss: 1.7592
# Epoch 60/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9587 - loss: 0.1414 - val_accuracy: 0.7585 - val_loss: 1.7588
# Epoch 61/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9598 - loss: 0.1325 - val_accuracy: 0.7629 - val_loss: 1.8718
# Epoch 62/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9595 - loss: 0.1310 - val_accuracy: 0.7624 - val_loss: 1.8157
# Epoch 63/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9588 - loss: 0.1354 - val_accuracy: 0.7579 - val_loss: 1.8293
# Epoch 64/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9585 - loss: 0.1335 - val_accuracy: 0.7551 - val_loss: 1.8578
# Epoch 65/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9620 - loss: 0.1291 - val_accuracy: 0.7574 - val_loss: 1.8641
# Epoch 66/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9594 - loss: 0.1331 - val_accuracy: 0.7596 - val_loss: 1.8565
# Epoch 67/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9621 - loss: 0.1208 - val_accuracy: 0.7624 - val_loss: 1.8875
# Epoch 68/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9594 - loss: 0.1327 - val_accuracy: 0.7635 - val_loss: 1.8914
# Epoch 69/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9614 - loss: 0.1210 - val_accuracy: 0.7635 - val_loss: 1.8870
# Epoch 70/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9644 - loss: 0.1180 - val_accuracy: 0.7596 - val_loss: 1.9355
# Epoch 71/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9617 - loss: 0.1212 - val_accuracy: 0.7546 - val_loss: 1.9396
# Epoch 72/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9616 - loss: 0.1229 - val_accuracy: 0.7579 - val_loss: 1.9939
# Epoch 73/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9630 - loss: 0.1214 - val_accuracy: 0.7607 - val_loss: 1.9612
# Epoch 74/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9608 - loss: 0.1182 - val_accuracy: 0.7551 - val_loss: 1.9895
# Epoch 75/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9621 - loss: 0.1172 - val_accuracy: 0.7513 - val_loss: 2.0089
# Epoch 76/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9616 - loss: 0.1219 - val_accuracy: 0.7529 - val_loss: 2.0567
# Epoch 77/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9617 - loss: 0.1184 - val_accuracy: 0.7513 - val_loss: 2.0913
# Epoch 78/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9621 - loss: 0.1151 - val_accuracy: 0.7574 - val_loss: 2.0569
# Epoch 79/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9630 - loss: 0.1130 - val_accuracy: 0.7551 - val_loss: 2.0484
# Epoch 80/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9631 - loss: 0.1111 - val_accuracy: 0.7557 - val_loss: 2.0988
# Epoch 81/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9648 - loss: 0.1016 - val_accuracy: 0.7546 - val_loss: 2.1364
# Epoch 82/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9621 - loss: 0.1102 - val_accuracy: 0.7496 - val_loss: 2.1064
# Epoch 83/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9623 - loss: 0.1106 - val_accuracy: 0.7507 - val_loss: 2.1533
# Epoch 84/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9635 - loss: 0.1083 - val_accuracy: 0.7524 - val_loss: 2.1141
# Epoch 85/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9614 - loss: 0.1162 - val_accuracy: 0.7535 - val_loss: 2.1472
# Epoch 86/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9652 - loss: 0.1070 - val_accuracy: 0.7485 - val_loss: 2.1728
# Epoch 87/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9645 - loss: 0.1021 - val_accuracy: 0.7574 - val_loss: 2.1898
# Epoch 88/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9638 - loss: 0.1023 - val_accuracy: 0.7579 - val_loss: 2.1370
# Epoch 89/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9617 - loss: 0.1146 - val_accuracy: 0.7496 - val_loss: 2.1983
# Epoch 90/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9627 - loss: 0.1115 - val_accuracy: 0.7513 - val_loss: 2.1755
# Epoch 91/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9619 - loss: 0.1135 - val_accuracy: 0.7535 - val_loss: 2.1743
# Epoch 92/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9620 - loss: 0.1110 - val_accuracy: 0.7507 - val_loss: 2.1826
# Epoch 93/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9630 - loss: 0.1105 - val_accuracy: 0.7518 - val_loss: 2.2176
# Epoch 94/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9616 - loss: 0.1064 - val_accuracy: 0.7507 - val_loss: 2.1726
# Epoch 95/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9634 - loss: 0.1068 - val_accuracy: 0.7507 - val_loss: 2.2359
# Epoch 96/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9630 - loss: 0.1048 - val_accuracy: 0.7540 - val_loss: 2.3167
# Epoch 97/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9605 - loss: 0.1119 - val_accuracy: 0.7513 - val_loss: 2.2902
# Epoch 98/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9631 - loss: 0.1023 - val_accuracy: 0.7529 - val_loss: 2.3283
# Epoch 99/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9645 - loss: 0.1036 - val_accuracy: 0.7496 - val_loss: 2.2792
# Epoch 100/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9640 - loss: 0.1028 - val_accuracy: 0.7462 - val_loss: 2.3446
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7565 - loss: 2.3685
# Test Accuracy: 0.7565
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %% [markdown]
# ***Plot the results - train accuracy vs test accuracy and train loss vs. test loss***

# %%
import matplotlib.pyplot as plt

#accuracy plot
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

#loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ***Attempt embedding and multiple convolution layers***

# %%
#build tuned CNN model
cnn_model2 = Sequential([
    Embedding(input_dim=15000, output_dim=128),
    Conv1D(filters=128, kernel_size=5, activation='relu'),
    Conv1D(filters=128, kernel_size=5, activation='relu'),
    GlobalMaxPooling1D(),
    Dropout(0.4),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ***Compile the model, use Early Stopping to reduce fitting time if not gaining any additional accuracy***

# %%
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping

#compile with lower learning rate
cnn_model2.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

#early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

#train the model, increase epochs to 100 as Early Stopping is defined
history2 = cnn_model2.fit(
    x_train, y_train_cnn,
    epochs=100,
    batch_size=128,
    validation_split=0.2,
    callbacks=[early_stop],
    class_weight=class_weightings
)

#Evaluate the model
test_loss, test_acc = cnn_model2.evaluate(x_test, y_test_cnn)
print(f"Test Accuracy: {test_acc:.4f}")

y_pred_cnn2 = cnn_model2.predict(x_test)
y_pred_cnn2 = y_pred_cnn2.argmax(axis=1)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.3056 - loss: 3.5582 - val_accuracy: 0.3450 - val_loss: 2.6820
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.3481 - loss: 2.7839 - val_accuracy: 0.3450 - val_loss: 2.4877
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.3731 - loss: 2.6146 - val_accuracy: 0.4107 - val_loss: 2.2067
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.4728 - loss: 2.3780 - val_accuracy: 0.4953 - val_loss: 2.0718
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5009 - loss: 2.3083 - val_accuracy: 0.4981 - val_loss: 2.0261
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5061 - loss: 2.2672 - val_accuracy: 0.5081 - val_loss: 1.9787
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5090 - loss: 2.2167 - val_accuracy: 0.5153 - val_loss: 1.9302
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5133 - loss: 2.1504 - val_accuracy: 0.5209 - val_loss: 1.8657
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5186 - loss: 2.0847 - val_accuracy: 0.5253 - val_loss: 1.7948
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5328 - loss: 2.0145 - val_accuracy: 0.5448 - val_loss: 1.7436
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5592 - loss: 1.9569 - val_accuracy: 0.5632 - val_loss: 1.6949
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5781 - loss: 1.9075 - val_accuracy: 0.5748 - val_loss: 1.6591
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5961 - loss: 1.8610 - val_accuracy: 0.5915 - val_loss: 1.6262
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6086 - loss: 1.8162 - val_accuracy: 0.6177 - val_loss: 1.5954
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6237 - loss: 1.7765 - val_accuracy: 0.6316 - val_loss: 1.5670
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6419 - loss: 1.7357 - val_accuracy: 0.6405 - val_loss: 1.5430
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6555 - loss: 1.6945 - val_accuracy: 0.6500 - val_loss: 1.5054
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6656 - loss: 1.6484 - val_accuracy: 0.6605 - val_loss: 1.4758
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6775 - loss: 1.6048 - val_accuracy: 0.6644 - val_loss: 1.4476
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6866 - loss: 1.5602 - val_accuracy: 0.6745 - val_loss: 1.4170
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6945 - loss: 1.5180 - val_accuracy: 0.6761 - val_loss: 1.3903
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7030 - loss: 1.4714 - val_accuracy: 0.6789 - val_loss: 1.3708
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7069 - loss: 1.4289 - val_accuracy: 0.6811 - val_loss: 1.3569
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7140 - loss: 1.4004 - val_accuracy: 0.6811 - val_loss: 1.3452
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7159 - loss: 1.3647 - val_accuracy: 0.6806 - val_loss: 1.3383
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7222 - loss: 1.3276 - val_accuracy: 0.6795 - val_loss: 1.3327
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7261 - loss: 1.3007 - val_accuracy: 0.6822 - val_loss: 1.3285
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7357 - loss: 1.2693 - val_accuracy: 0.6900 - val_loss: 1.3271
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7406 - loss: 1.2347 - val_accuracy: 0.6895 - val_loss: 1.3299
# Epoch 30/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7491 - loss: 1.2023 - val_accuracy: 0.6956 - val_loss: 1.3333
# Epoch 31/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7578 - loss: 1.1681 - val_accuracy: 0.6934 - val_loss: 1.3410
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6874 - loss: 1.3438
# Test Accuracy: 0.6874
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %% [markdown]
# ***Plot the results after using extra convoluting layers and early stopping***

# %%
#plot training curves
plt.figure(figsize=(10, 4))

#accuracy
plt.subplot(1, 2, 1)
plt.plot(history2.history['accuracy'], label='Train Accuracy')
plt.plot(history2.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

#loss
plt.subplot(1, 2, 2)
plt.plot(history2.history['loss'], label='Train Loss')
plt.plot(history2.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Phase 3: Now create a CNN architecture with multiple filter sizes and richer feature extraction** #

# %%
# Number of words should match input dimensions
num_words = 15000

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Concatenate

input_layer = Input(shape=(maxlen,))
embedding = Embedding(input_dim=15000, output_dim=128)(input_layer)

branch_ksize3 = Conv1D(filters=128, kernel_size=3, activation='relu')(embedding)
branch_ksize3 = GlobalMaxPooling1D()(branch_ksize3)

branch_ksize4 = Conv1D(filters=128, kernel_size=4, activation='relu')(embedding)
branch_ksize4 = GlobalMaxPooling1D()(branch_ksize4)

branch_ksize5 = Conv1D(filters=128, kernel_size=5, activation='relu')(embedding)
branch_ksize5 = GlobalMaxPooling1D()(branch_ksize5)

merged_branches = Concatenate()([branch_ksize3, branch_ksize4, branch_ksize5])
merged_branches = Dropout(0.27)(merged_branches)
merged_branches = Dense(128, activation='relu')(merged_branches)
output = Dense(num_classes, activation='softmax')(merged_branches)

cnn_model3 = Model(inputs=input_layer, outputs=output)

# Compile
cnn_model3.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0004),
    metrics=['accuracy']
)

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model
history3 = cnn_model3.fit(
    x_train, y_train_cnn,
    epochs=100,
    batch_size=128,
    validation_split=0.2,
    class_weight=class_weightings,
    callbacks=[early_stop]
)

test_loss, test_acc = cnn_model3.evaluate(x_test, y_test_cnn)
print(f"Test Accuracy: {test_acc:.4f}")

y_pred_cnn3 = cnn_model3.predict(x_test)
y_pred_cnn3 = y_pred_cnn3.argmax(axis=1)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.3919 - loss: 2.8323 - val_accuracy: 0.4925 - val_loss: 2.0322
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.4997 - loss: 2.1861 - val_accuracy: 0.5114 - val_loss: 1.8630
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5628 - loss: 1.9780 - val_accuracy: 0.6093 - val_loss: 1.6222
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.6610 - loss: 1.7371 - val_accuracy: 0.6784 - val_loss: 1.4019
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.6931 - loss: 1.5403 - val_accuracy: 0.6995 - val_loss: 1.2766
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7201 - loss: 1.3901 - val_accuracy: 0.7240 - val_loss: 1.2043
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7510 - loss: 1.2527 - val_accuracy: 0.7396 - val_loss: 1.1370
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7791 - loss: 1.1246 - val_accuracy: 0.7568 - val_loss: 1.0656
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8077 - loss: 1.0009 - val_accuracy: 0.7796 - val_loss: 1.0119
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8299 - loss: 0.8807 - val_accuracy: 0.7874 - val_loss: 0.9563
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8508 - loss: 0.7724 - val_accuracy: 0.7919 - val_loss: 0.9128
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8646 - loss: 0.6771 - val_accuracy: 0.7980 - val_loss: 0.8778
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8821 - loss: 0.5811 - val_accuracy: 0.8047 - val_loss: 0.8562
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9015 - loss: 0.5000 - val_accuracy: 0.8058 - val_loss: 0.8411
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9151 - loss: 0.4295 - val_accuracy: 0.8119 - val_loss: 0.8367
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9260 - loss: 0.3729 - val_accuracy: 0.8136 - val_loss: 0.8359
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9340 - loss: 0.3236 - val_accuracy: 0.8164 - val_loss: 0.8474
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9463 - loss: 0.2748 - val_accuracy: 0.8119 - val_loss: 0.8590
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9499 - loss: 0.2486 - val_accuracy: 0.8147 - val_loss: 0.8611
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8045 - loss: 0.8622
# Test Accuracy: 0.8045
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %%
# plot training curves
plt.figure(figsize=(10, 4))

#accuracy
plt.subplot(1, 2, 1)
plt.plot(history3.history['accuracy'], label='Train Accuracy')
plt.plot(history3.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

#loss
plt.subplot(1, 2, 2)
plt.plot(history3.history['loss'], label='Train Loss')
plt.plot(history3.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Phase 4: Using tuned CNN with GLoVe, allowing the model to focus on classification instead of also needing to learn word interpretations from scratch** #

# %%
#num_words and maxlen already defined during SVM training

tokenizer = Tokenizer(num_words=num_words, oov_token="<UNK>") #<UNK> is a 'catch-all'
tokenizer.fit_on_texts(X_train_text) # build an internal vocabulary

# Make sequences for train and test sets
X_train_seq = tokenizer.texts_to_sequences(X_train_text)
X_test_seq = tokenizer.texts_to_sequences(X_test_text)

# pad them so each entry is the same length
X_train_pad = pad_sequences(X_train_seq, maxlen=maxlen)
X_test_pad = pad_sequences(X_test_seq, maxlen=maxlen)

# %% [markdown]
# ***Gensim allows loading of the GLoVe vector file through an API instead of needing to download it***

# %%
# Needed if Gensim module not installed
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 88.0 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import gensim.downloader as api
word_vectors = api.load("glove-wiki-gigaword-100")
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %% [markdown]
# ***Build the GloVe embedding matrix***

# %%
embedding_dim = 100
embedding_matrix = {}

vocab_size = min(num_words, len(tokenizer.word_index) + 1)
embedding_matrix = np.zeros((vocab_size, embedding_dim))

for word, i in tokenizer.word_index.items():
    if i >= vocab_size:
        continue
    if word in word_vectors:
      embedding_vector = word_vectors[word]
    else:
      embedding_vector = None
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# ***Build the CNN model using the GLoVe file in the Embedding layer***

# %%
input_layer = Input(shape=(maxlen,)) #define the input

# Apply the embedding layer
embedding = Embedding(
    input_dim=vocab_size,
    output_dim=embedding_dim,
    weights=[embedding_matrix],
    trainable=False
)

# Set up embedding layer as a Tensor, as needed for the CNN branches
embedding_GLoVe = embedding(input_layer)

branch_ksize3 = Conv1D(filters=128, kernel_size=3, activation='relu')(embedding_GLoVe)
branch_ksize3 = GlobalMaxPooling1D()(branch_ksize3)

branch_ksize4 = Conv1D(filters=128, kernel_size=4, activation='relu')(embedding_GLoVe)
branch_ksize4 = GlobalMaxPooling1D()(branch_ksize4)

branch_ksize5 = Conv1D(filters=128, kernel_size=5, activation='relu')(embedding_GLoVe)
branch_ksize5 = GlobalMaxPooling1D()(branch_ksize5)

merged_branches = Concatenate()([branch_ksize3, branch_ksize4, branch_ksize5])
merged_branches = Dropout(0.27)(merged_branches)
merged_branches = Dense(128, activation='relu')(merged_branches)
output = Dense(num_classes, activation='softmax')(merged_branches)

cnn_model4 = Model(inputs=input_layer, outputs=output)

# Compile
cnn_model4.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0004),
    metrics=['accuracy']
)

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model
history4 = cnn_model4.fit(
    x_train, y_train_cnn,
    epochs=100,
    batch_size=128,
    validation_split=0.2,
    class_weight=class_weightings,
    callbacks=[early_stop]
)

test_loss, test_acc = cnn_model4.evaluate(x_test, y_test_cnn)
print(f"Test Accuracy: {test_acc:.4f}")

y_pred_cnn4 = cnn_model4.predict(x_test)
y_pred_cnn4 = y_pred_cnn4.argmax(axis=1)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 9s 86ms/step - accuracy: 0.3794 - loss: 2.7650 - val_accuracy: 0.4869 - val_loss: 2.1457
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4761 - loss: 2.3234 - val_accuracy: 0.4953 - val_loss: 1.9260
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5093 - loss: 2.1426 - val_accuracy: 0.5487 - val_loss: 1.8074
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5553 - loss: 1.9919 - val_accuracy: 0.5993 - val_loss: 1.6966
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5910 - loss: 1.8510 - val_accuracy: 0.6338 - val_loss: 1.5911
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6260 - loss: 1.7374 - val_accuracy: 0.6260 - val_loss: 1.5342
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6495 - loss: 1.6106 - val_accuracy: 0.6622 - val_loss: 1.4537
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6696 - loss: 1.5055 - val_accuracy: 0.6767 - val_loss: 1.4033
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6907 - loss: 1.4033 - val_accuracy: 0.6722 - val_loss: 1.3626
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7091 - loss: 1.3125 - val_accuracy: 0.6928 - val_loss: 1.3189
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7356 - loss: 1.2176 - val_accuracy: 0.6978 - val_loss: 1.2736
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7562 - loss: 1.1241 - val_accuracy: 0.7084 - val_loss: 1.2506
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7729 - loss: 1.0377 - val_accuracy: 0.7101 - val_loss: 1.2264
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7916 - loss: 0.9747 - val_accuracy: 0.7223 - val_loss: 1.1968
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8075 - loss: 0.8859 - val_accuracy: 0.7318 - val_loss: 1.2029
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8248 - loss: 0.8283 - val_accuracy: 0.7412 - val_loss: 1.1363
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8381 - loss: 0.7592 - val_accuracy: 0.7368 - val_loss: 1.1210
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8533 - loss: 0.7070 - val_accuracy: 0.7401 - val_loss: 1.1275
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8626 - loss: 0.6435 - val_accuracy: 0.7474 - val_loss: 1.1019
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8678 - loss: 0.5989 - val_accuracy: 0.7435 - val_loss: 1.0887
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8789 - loss: 0.5558 - val_accuracy: 0.7435 - val_loss: 1.0959
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8849 - loss: 0.5164 - val_accuracy: 0.7535 - val_loss: 1.0716
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8992 - loss: 0.4659 - val_accuracy: 0.7468 - val_loss: 1.0860
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9012 - loss: 0.4520 - val_accuracy: 0.7462 - val_loss: 1.0807
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9070 - loss: 0.4230 - val_accuracy: 0.7446 - val_loss: 1.0887
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7355 - loss: 1.1016
# Test Accuracy: 0.7355
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %% [markdown]
# ***Plot the results***

# %%
# plot training curves
plt.figure(figsize=(10, 4))

#accuracy
plt.subplot(1, 2, 1)
plt.plot(history4.history['accuracy'], label='Train Accuracy')
plt.plot(history4.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

#loss
plt.subplot(1, 2, 2)
plt.plot(history4.history['loss'], label='Train Loss')
plt.plot(history4.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Compare the results of the tuned SVM model and all CNN models** #

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
# Combine the results into a list
list_of_model_results = {
    "SVM": (y_test, y_pred_svm),
    "CNN_1": (y_test_cnn, y_pred_cnn),
    "CNN_2": (y_test_cnn, y_pred_cnn2),
    "CNN_3": (y_test_cnn, y_pred_cnn3),
    "CNN_4": (y_test_cnn, y_pred_cnn4)
}

# Tabulate the results
results_array = []

for name, (y_true, y_pred) in list_of_model_results.items():

    # Convert one-hot encoded true labels back to class labels if needed
    if len(y_true.shape) > 1:
        y_true_classes = np.argmax(y_true, axis=1)
    else:
        y_true_classes = y_true

    # Convert predicted probabilities back to class labels if needed
    if len(y_pred.shape) > 1:
        y_pred_classes = np.argmax(y_pred, axis=1)
    else:
        y_pred_classes = y_pred

    results_array.append({
        "Model": name,
        "Accuracy": accuracy_score(y_true_classes, y_pred_classes),
        "Precision": precision_score(y_true_classes, y_pred_classes, average='weighted', zero_division=0),
        "Recall": recall_score(y_true_classes, y_pred_classes, average='weighted', zero_division=0),
        "F1 Score": f1_score(y_true_classes, y_pred_classes, average='weighted', zero_division=0),
        "F1 Macro Score": f1_score(y_true_classes, y_pred_classes, average='macro', zero_division=0)
    })

df_results = pd.DataFrame(results_array)
print(df_results)
# Out:
#    Model  Accuracy  Precision    Recall  F1 Score  F1 Macro Score
# 0    SVM  0.830810   0.838305  0.830810  0.831235        0.695465
# 1  CNN_1  0.756456   0.745834  0.756456  0.742943        0.505468
# 2  CNN_2  0.687444   0.607745  0.687444  0.629722        0.107309
# 3  CNN_3  0.804541   0.798768  0.804541  0.796206        0.551629
# 4  CNN_4  0.735530   0.721432  0.735530  0.715240        0.397698

# %% [markdown]
# # **Provide class labels for further display** #

# %%
reuters_labels = [
    "cocoa",                # 0
    "grain",                # 1
    "veg-oil",              # 2
    "earn",                 # 3
    "acq",                  # 4
    "wheat",                # 5
    "copper",               # 6
    "housing",             # 7
    "money-supply",        # 8
    "coffee",              # 9
    "sugar",               # 10
    "trade",               # 11
    "reserves",            # 12
    "ship",                # 13
    "cotton",              # 14
    "carcass",             # 15
    "crude",               # 16
    "nat-gas",             # 17
    "cpi",                 # 18
    "money-fx",            # 19
    "interest",            # 20
    "gnp",                 # 21
    "meal-feed",           # 22
    "alum",                # 23
    "oilseed",             # 24
    "gold",                # 25
    "tin",                 # 26
    "strategic-metal",     # 27
    "livestock",           # 28
    "retail",              # 29
    "ipi",                 # 30
    "iron-steel",          # 31
    "rubber",              # 32
    "heat",                # 33
    "jobs",                # 34
    "lei",                 # 35
    "bop",                 # 36
    "zinc",                # 37
    "orange",              # 38
    "pet-chem",            # 39
    "dlr",                 # 40
    "gas",                 # 41
    "silver",              # 42
    "wpi",                 # 43
    "hog",                 # 44
    "lead"                 # 45
]

# %% [markdown]
# # **Dump files** #

# %%
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (1.5.3)

# %%
import joblib

# Class labels
joblib.dump(reuters_labels, f"{MODELS_PATH}/reuter_class_labels.pkl")

# SVM
import joblib
joblib.dump(svm_model, f"{MODELS_PATH}/svm_model.pkl")
joblib.dump(vector, f"{MODELS_PATH}/tfidf_vectorizer.pkl")

# CNN
cnn_model3.save(f"{MODELS_PATH}/cnn_model.keras")
joblib.dump(tokenizer, f"{MODELS_PATH}/tokenizer.pkl")
joblib.dump(maxlen, f"{MODELS_PATH}/maxlen.pkl")
# Out:
# ['/content/drive/MyDrive/reuters_text_classification/models/maxlen.pkl']
