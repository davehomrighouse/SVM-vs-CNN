# %% [markdown]
# # **Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
BASE_PATH = "/content/drive/MyDrive/reuters_text_classification"
MODELS_PATH = f"{BASE_PATH}/models"
NOTEBOOKS_PATH = f"{BASE_PATH}/notebooks"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Data download and preprocessing** #

# %% [markdown]
# ***Download and split the data***

# %%
from tensorflow.keras.datasets import reuters
from sklearn.model_selection import train_test_split
import numpy as np

# Load dataset with an 80/20 split between training and testing
(X_train, y_train), (X_test, y_test) = reuters.load_data(test_split=0.2)

# See the first few rows of X_train and y_train to verify the download worked
print(X_train[:3])
print('\n',y_train[:3])
# Out:
# [list([1, 27595, 28842, 8, 43, 10, 447, 5, 25, 207, 270, 5, 3095, 111, 16, 369, 186, 90, 67, 7, 89, 5, 19, 102, 6, 19, 124, 15, 90, 67, 84, 22, 482, 26, 7, 48, 4, 49, 8, 864, 39, 209, 154, 6, 151, 6, 83, 11, 15, 22, 155, 11, 15, 7, 48, 9, 4579, 1005, 504, 6, 258, 6, 272, 11, 15, 22, 134, 44, 11, 15, 16, 8, 197, 1245, 90, 67, 52, 29, 209, 30, 32, 132, 6, 109, 15, 17, 12])
#  list([1, 3267, 699, 3434, 2295, 56, 16784, 7511, 9, 56, 3906, 1073, 81, 5, 1198, 57, 366, 737, 132, 20, 4093, 7, 19261, 49, 2295, 13415, 1037, 3267, 699, 3434, 8, 7, 10, 241, 16, 855, 129, 231, 783, 5, 4, 587, 2295, 13415, 30625, 775, 7, 48, 34, 191, 44, 35, 1795, 505, 17, 12])
#  list([1, 53, 12, 284, 15, 14, 272, 26, 53, 959, 32, 818, 15, 14, 272, 26, 39, 684, 70, 11, 14, 12, 3886, 18, 180, 183, 187, 70, 11, 14, 102, 32, 11, 29, 53, 44, 704, 15, 14, 19, 758, 15, 53, 959, 47, 1013, 15, 14, 19, 132, 15, 39, 965, 32, 11, 14, 147, 72, 11, 180, 183, 187, 44, 11, 14, 102, 19, 11, 123, 186, 90, 67, 960, 4, 78, 13, 68, 467, 511, 110, 59, 89, 90, 67, 1390, 55, 2678, 92, 617, 80, 1274, 46, 905, 220, 13, 4, 346, 48, 235, 629, 5, 211, 5, 1118, 7, 11733, 81, 5, 187, 11, 15, 9, 1709, 201, 5, 47, 3615, 18, 478, 4514, 5, 1118, 7, 232, 13051, 71, 5, 160, 63, 11, 9, 26503, 81, 5, 102, 59, 11, 17, 12])]
#
#  [3 4 3]

# %% [markdown]
# ***Translate integers to words***

# %%
# Get the word-to-index mapping
word_index = reuters.get_word_index()

# Flip it so it becomes an index-to-word mapping
text_index = {value: key for key, value in word_index.items()}

# Test if it works
print(text_index[27595])
# Out:
# wattie

# %% [markdown]
# ***Vectorize the training dataset***

# %%
# Array will hold the decoded text for X_train
X_train_text = []

# Decode training data from integer into text
for index_word_pair in X_train:
    X_train_word_array = []
    for this_word in index_word_pair:
        current_word = text_index.get(this_word - 3, '?')
        X_train_word_array.append(current_word)
    current_sentence = ' '.join(X_train_word_array)
    X_train_text.append(current_sentence)

# %% [markdown]
# ***Vectorize the testing dataset***

# %%
# Array will hold the decoded text for X_test
X_test_text = []

# Decode test data
for index_word_pair in X_test:
    X_test_word_array = []
    for this_word in index_word_pair:
        current_word = text_index.get(this_word - 3, '?')
        X_test_word_array.append(current_word)
    X_test_sentence = ' '.join(X_test_word_array)
    X_test_text.append(X_test_sentence)

# %% [markdown]
# ***Convert text to TF-IDF vectors for SVM model***

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import TfidfVectorizer as tfidf

# Convert text
vector = tfidf(max_features=None,  # Let min_df/max_df decide
               min_df=5,
               max_df=0.9)
X_train_vector = vector.fit_transform(X_train_text)
X_test_vector = vector.transform(X_test_text)
print(len(vector.vocabulary_))
# Out:
# 9101

# %% [markdown]
# # **Phase 1: SVM model**

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report, accuracy_score

# Choose C=1 as an initial C
svm_model = LinearSVC(C=1,
                      class_weight = 'balanced')
svm_model.fit(X_train_vector, y_train)

# Perform initial predictions and evaluate results
y_pred_svm = svm_model.predict(X_test_vector)
print(f"Accuracy: {accuracy_score(y_test, y_pred_svm)}")
print(f"Classification report:\n{classification_report(y_test, y_pred_svm)}")
# Out:
# Accuracy: 0.8308103294746215
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.76      0.77      0.77       105
#            2       0.77      0.85      0.81        20
#            3       0.95      0.92      0.93       813
#            4       0.87      0.88      0.87       474
#            5       0.33      0.20      0.25         5
#            6       0.81      0.93      0.87        14
#            7       0.75      1.00      0.86         3
#            8       0.66      0.71      0.68        38
#            9       0.80      0.96      0.87        25
#           10       0.82      0.93      0.88        30
#           11       0.70      0.73      0.72        83
#           12       0.50      0.54      0.52        13
#           13       0.67      0.76      0.71        37
#           14       0.29      1.00      0.44         2
#           15       0.67      0.44      0.53         9
#           16       0.77      0.82      0.79        99
#           17       0.71      0.83      0.77        12
#           18       0.74      0.70      0.72        20
#           19       0.80      0.66      0.72       133
#           20       0.58      0.61      0.60        70
#           21       0.56      0.89      0.69        27
#           22       1.00      0.29      0.44         7
#           23       0.67      0.83      0.74        12
#           24       0.58      0.58      0.58        19
#           25       0.88      0.94      0.91        31
#           26       0.88      0.88      0.88         8
#           27       0.67      0.50      0.57         4
#           28       0.44      0.40      0.42        10
#           29       0.50      1.00      0.67         4
#           30       1.00      0.75      0.86        12
#           31       0.82      0.69      0.75        13
#           32       0.91      1.00      0.95        10
#           33       0.80      0.80      0.80         5
#           34       0.80      0.57      0.67         7
#           35       1.00      0.67      0.80         6
#           36       0.46      0.55      0.50        11
#           37       0.50      1.00      0.67         2
#           38       0.67      0.67      0.67         3
#           39       0.40      0.40      0.40         5
#           40       0.60      0.30      0.40        10
#           41       0.71      0.62      0.67         8
#           42       1.00      0.67      0.80         3
#           43       0.67      1.00      0.80         6
#           44       0.57      0.80      0.67         5
#           45       0.50      1.00      0.67         1
#
#     accuracy                           0.83      2246
#    macro avg       0.70      0.73      0.70      2246
# weighted avg       0.84      0.83      0.83      2246

# %% [markdown]
# ***Attempt to improve the model by tuning the hyperparamter C***

# %%
from sklearn.model_selection import cross_val_score

# Test different C values
c_values = [0.01, 0.1, 1.0, 10.0, 100.0]
best_C = None
best_score = 0

# Iterate over the 5 c_values
for test_c in c_values:

    # create a model based on test_c
    svm_model = LinearSVC(C=test_c)  #Linear is best for clean text

    # Score the model on 5-fold cross-validation. Use n_jobs=-1 for speed purposes
    result = cross_val_score(svm_model, X_train_vector, y_train, cv=5, scoring='accuracy', n_jobs=-1)

    # Average the resultant scores
    ave_result = np.mean(result)

    # Print the averaged accuracy and standard deviation
    print(f"C={test_c}: Mean CV Accuracy = {ave_result:.4f} (±{np.std(result):.4f})")

    # Hold the C value based on the best average mean score
    if ave_result > best_score:
        best_score = ave_result
        best_C = test_c

# Print best C
print("\nBest C value:", best_C)
print("Best mean CV accuracy:", best_score)
# Out:
# C=0.01: Mean CV Accuracy = 0.6899 (±0.0064)
# C=0.1: Mean CV Accuracy = 0.8308 (±0.0062)
# C=1.0: Mean CV Accuracy = 0.8408 (±0.0063)
# C=10.0: Mean CV Accuracy = 0.8199 (±0.0060)
# C=100.0: Mean CV Accuracy = 0.8110 (±0.0048)
#
# Best C value: 1.0
# Best mean CV accuracy: 0.8407933043565556

# %% [markdown]
# ***A C-value of 1 had the best accuracy (in my run). Further tuning by setting C-values between 1 and 10, inclusive***

# %%
c_values = range(1, 11)
best_C = None
best_score = 0

# Iterate over the 10 c_values
for test_c in c_values:
    # create a model based on test_c
    svm_model = LinearSVC(C=test_c)

    # Score the model on 5-fold cross-validation. Use n_jobs=-1 for speed purposes
    result = cross_val_score(svm_model, X_train_vector, y_train, cv=5, scoring='accuracy', n_jobs=-1)

    # Average the resultant scores
    ave_result = np.mean(result)

    # Print the averaged accuracy and standard deviation
    print(f"C={test_c}: Mean CV Accuracy = {ave_result:.4f} (±{np.std(result):.4f})")

    # Hold the C value based on the best average mean score
    if ave_result > best_score:
        best_score = ave_result
        best_C = test_c

# Print best C
print("\nBest C value:", best_C)
print("Best mean CV accuracy:", best_score)
# Out:
# C=1: Mean CV Accuracy = 0.8408 (±0.0063)
# C=2: Mean CV Accuracy = 0.8314 (±0.0069)
# C=3: Mean CV Accuracy = 0.8271 (±0.0060)
# C=4: Mean CV Accuracy = 0.8257 (±0.0057)
# C=5: Mean CV Accuracy = 0.8235 (±0.0054)
# C=6: Mean CV Accuracy = 0.8222 (±0.0050)
# C=7: Mean CV Accuracy = 0.8213 (±0.0056)
# C=8: Mean CV Accuracy = 0.8206 (±0.0056)
# C=9: Mean CV Accuracy = 0.8203 (±0.0059)
# C=10: Mean CV Accuracy = 0.8199 (±0.0060)
#
# Best C value: 1
# Best mean CV accuracy: 0.8407933043565556

# %% [markdown]
# ***Fit the model with the best C-value and display the accuracy***

# %%
# Choose C=1 as it was determined to be the best value
svm_model = LinearSVC(C=1,
                      class_weight = 'balanced')
svm_model = svm_model.fit(X_train_vector, y_train)

# Perform predictions and evaluate results
y_pred_svm = svm_model.predict(X_test_vector)
print(f"Accuracy: {accuracy_score(y_test, y_pred_svm):.3f}\n")
print(f"Classification report:\n{classification_report(y_test, y_pred_svm)}")
# Out:
# Accuracy: 0.831
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.76      0.77      0.77       105
#            2       0.77      0.85      0.81        20
#            3       0.95      0.92      0.93       813
#            4       0.87      0.88      0.87       474
#            5       0.33      0.20      0.25         5
#            6       0.81      0.93      0.87        14
#            7       0.75      1.00      0.86         3
#            8       0.66      0.71      0.68        38
#            9       0.80      0.96      0.87        25
#           10       0.82      0.93      0.88        30
#           11       0.70      0.73      0.72        83
#           12       0.50      0.54      0.52        13
#           13       0.67      0.76      0.71        37
#           14       0.29      1.00      0.44         2
#           15       0.67      0.44      0.53         9
#           16       0.77      0.82      0.79        99
#           17       0.71      0.83      0.77        12
#           18       0.74      0.70      0.72        20
#           19       0.80      0.66      0.72       133
#           20       0.58      0.61      0.60        70
#           21       0.56      0.89      0.69        27
#           22       1.00      0.29      0.44         7
#           23       0.67      0.83      0.74        12
#           24       0.58      0.58      0.58        19
#           25       0.88      0.94      0.91        31
#           26       0.88      0.88      0.88         8
#           27       0.67      0.50      0.57         4
#           28       0.44      0.40      0.42        10
#           29       0.50      1.00      0.67         4
#           30       1.00      0.75      0.86        12
#           31       0.82      0.69      0.75        13
#           32       0.91      1.00      0.95        10
#           33       0.80      0.80      0.80         5
#           34       0.80      0.57      0.67         7
#           35       1.00      0.67      0.80         6
#           36       0.46      0.55      0.50        11
#           37       0.50      1.00      0.67         2
#           38       0.67      0.67      0.67         3
#           39       0.40      0.40      0.40         5
#           40       0.60      0.30      0.40        10
#           41       0.71      0.62      0.67         8
#           42       1.00      0.67      0.80         3
#           43       0.67      1.00      0.80         6
#           44       0.57      0.80      0.67         5
#           45       0.50      1.00      0.67         1
#
#     accuracy                           0.83      2246
#    macro avg       0.70      0.73      0.70      2246
# weighted avg       0.84      0.83      0.83      2246

# %% [markdown]
# # **Phase 2: Build the CNN model using raw integer sequences**

# %% [markdown]
# ***This piece will help increase visibility of minor classes without pulling down weighting (much) of major classes***

# %%
def scaled_class_weights(base_dict, scale):
    return {cls: 1.0 + (w - 1.0) * scale for cls, w in base_dict.items()}

# %% [markdown]
# ***Load the data and build the training and test sets***

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
#load
(x_train, y_train), (x_test, y_test) = reuters.load_data(num_words=15000)

#pad sequence
maxlen = 300
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

#number of classes
num_classes = int(np.max(y_train) + 1)

# %% [markdown]
# ***Change the label values to categories by one-hot encoding***

# %%
from tensorflow.keras.utils import to_categorical
#oneHot Encode Labels
y_train_cnn = to_categorical(y_train, num_classes)
y_test_cnn = to_categorical(y_test, num_classes)

# %% [markdown]
# ***Create class weighting dictionary***

# %%
from sklearn.utils.class_weight import compute_class_weight

# y_train is one-hot encoded so convert back to class IDs
y_train_labels = np.argmax(y_train_cnn, axis=1)

# Load the class labels
classes = np.unique(y_train_labels)

# Compute the weights
weights = compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=y_train_labels
)

# Fill the dictionary
class_weight_dict = dict(zip(classes, weights))

# Retrieve and save the weightings.
class_weightings = scaled_class_weights(class_weight_dict, 0.1)

# %% [markdown]
# ***Import libraries and build the model***

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout

#build CNN Model
cnn_model = Sequential([
    Embedding(input_dim=15000, output_dim=128),
    Conv1D(filters=64, kernel_size=5, activation='relu'),
    GlobalMaxPooling1D(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ***Compile the model***

# %%
#complile the CNN model
cnn_model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %% [markdown]
# ***Train and evaluate the model***

# %%
history = cnn_model.fit(
    x_train, y_train_cnn,
    epochs=100, # no early stopping set yet
    batch_size=128,
    validation_split=0.2,
    class_weight=class_weightings
)

# Evaluate the results
test_loss, test_acc = cnn_model.evaluate(x_test, y_test_cnn)
print(f"Test Accuracy: {test_acc:.4f}")

# Save the predictions for later comparisons
y_pred_cnn = cnn_model.predict(x_test)
y_pred_cnn_classes = y_pred_cnn.argmax(axis=1)
y_true_cnn_classes = np.argmax(y_test_cnn, axis=1)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - accuracy: 0.3829 - loss: 2.8025 - val_accuracy: 0.4919 - val_loss: 1.9824
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4990 - loss: 2.1602 - val_accuracy: 0.5359 - val_loss: 1.7745
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5854 - loss: 1.9237 - val_accuracy: 0.6511 - val_loss: 1.5203
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6412 - loss: 1.7209 - val_accuracy: 0.6912 - val_loss: 1.3633
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6788 - loss: 1.5405 - val_accuracy: 0.7112 - val_loss: 1.2502
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7113 - loss: 1.3861 - val_accuracy: 0.7279 - val_loss: 1.1735
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7404 - loss: 1.2610 - val_accuracy: 0.7457 - val_loss: 1.1243
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7673 - loss: 1.1224 - val_accuracy: 0.7557 - val_loss: 1.0827
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7958 - loss: 0.9958 - val_accuracy: 0.7607 - val_loss: 1.0563
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8142 - loss: 0.8839 - val_accuracy: 0.7674 - val_loss: 1.0538
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8395 - loss: 0.7836 - val_accuracy: 0.7774 - val_loss: 1.0348
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8585 - loss: 0.6894 - val_accuracy: 0.7741 - val_loss: 1.0372
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8710 - loss: 0.6233 - val_accuracy: 0.7863 - val_loss: 1.0475
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8894 - loss: 0.5444 - val_accuracy: 0.7841 - val_loss: 1.0504
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8967 - loss: 0.4964 - val_accuracy: 0.7846 - val_loss: 1.0829
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9029 - loss: 0.4493 - val_accuracy: 0.7807 - val_loss: 1.0992
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9104 - loss: 0.4240 - val_accuracy: 0.7858 - val_loss: 1.1050
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9173 - loss: 0.3930 - val_accuracy: 0.7824 - val_loss: 1.1360
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9190 - loss: 0.3572 - val_accuracy: 0.7774 - val_loss: 1.1731
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9290 - loss: 0.3273 - val_accuracy: 0.7869 - val_loss: 1.1761
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9321 - loss: 0.3237 - val_accuracy: 0.7869 - val_loss: 1.2001
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9315 - loss: 0.3015 - val_accuracy: 0.7824 - val_loss: 1.2387
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9325 - loss: 0.2900 - val_accuracy: 0.7824 - val_loss: 1.2489
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9389 - loss: 0.2690 - val_accuracy: 0.7835 - val_loss: 1.2770
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9385 - loss: 0.2641 - val_accuracy: 0.7785 - val_loss: 1.3178
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9388 - loss: 0.2539 - val_accuracy: 0.7769 - val_loss: 1.3609
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9431 - loss: 0.2407 - val_accuracy: 0.7769 - val_loss: 1.3512
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9453 - loss: 0.2320 - val_accuracy: 0.7785 - val_loss: 1.3620
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9452 - loss: 0.2347 - val_accuracy: 0.7763 - val_loss: 1.3722
# Epoch 30/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9470 - loss: 0.2140 - val_accuracy: 0.7807 - val_loss: 1.4084
# Epoch 31/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9456 - loss: 0.2144 - val_accuracy: 0.7724 - val_loss: 1.4271
# Epoch 32/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9461 - loss: 0.2107 - val_accuracy: 0.7780 - val_loss: 1.4529
# Epoch 33/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9523 - loss: 0.1929 - val_accuracy: 0.7730 - val_loss: 1.4807
# Epoch 34/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9493 - loss: 0.1997 - val_accuracy: 0.7718 - val_loss: 1.4857
# Epoch 35/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9505 - loss: 0.1911 - val_accuracy: 0.7807 - val_loss: 1.4911
# Epoch 36/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9518 - loss: 0.1924 - val_accuracy: 0.7707 - val_loss: 1.5588
# Epoch 37/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9534 - loss: 0.1849 - val_accuracy: 0.7691 - val_loss: 1.5507
# Epoch 38/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9569 - loss: 0.1719 - val_accuracy: 0.7707 - val_loss: 1.5708
# Epoch 39/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9532 - loss: 0.1750 - val_accuracy: 0.7685 - val_loss: 1.5562
# Epoch 40/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9517 - loss: 0.1875 - val_accuracy: 0.7607 - val_loss: 1.5805
# Epoch 41/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9587 - loss: 0.1621 - val_accuracy: 0.7641 - val_loss: 1.6263
# Epoch 42/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9523 - loss: 0.1768 - val_accuracy: 0.7641 - val_loss: 1.6192
# Epoch 43/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9549 - loss: 0.1659 - val_accuracy: 0.7663 - val_loss: 1.6307
# Epoch 44/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9574 - loss: 0.1714 - val_accuracy: 0.7691 - val_loss: 1.6383
# Epoch 45/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9563 - loss: 0.1563 - val_accuracy: 0.7668 - val_loss: 1.6487
# Epoch 46/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9619 - loss: 0.1547 - val_accuracy: 0.7646 - val_loss: 1.6786
# Epoch 47/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9571 - loss: 0.1545 - val_accuracy: 0.7663 - val_loss: 1.6684
# Epoch 48/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9574 - loss: 0.1507 - val_accuracy: 0.7668 - val_loss: 1.6945
# Epoch 49/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9598 - loss: 0.1389 - val_accuracy: 0.7713 - val_loss: 1.7387
# Epoch 50/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9567 - loss: 0.1656 - val_accuracy: 0.7641 - val_loss: 1.7066
# Epoch 51/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9566 - loss: 0.1528 - val_accuracy: 0.7624 - val_loss: 1.7663
# Epoch 52/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9559 - loss: 0.1607 - val_accuracy: 0.7596 - val_loss: 1.7715
# Epoch 53/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9605 - loss: 0.1409 - val_accuracy: 0.7618 - val_loss: 1.7476
# Epoch 54/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9591 - loss: 0.1491 - val_accuracy: 0.7563 - val_loss: 1.8051
# Epoch 55/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9599 - loss: 0.1429 - val_accuracy: 0.7568 - val_loss: 1.8062
# Epoch 56/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9589 - loss: 0.1422 - val_accuracy: 0.7579 - val_loss: 1.7957
# Epoch 57/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9559 - loss: 0.1507 - val_accuracy: 0.7574 - val_loss: 1.8314
# Epoch 58/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9592 - loss: 0.1412 - val_accuracy: 0.7574 - val_loss: 1.8355
# Epoch 59/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9587 - loss: 0.1378 - val_accuracy: 0.7557 - val_loss: 1.8507
# Epoch 60/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9620 - loss: 0.1323 - val_accuracy: 0.7585 - val_loss: 1.8721
# Epoch 61/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9603 - loss: 0.1372 - val_accuracy: 0.7557 - val_loss: 1.9187
# Epoch 62/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9605 - loss: 0.1360 - val_accuracy: 0.7479 - val_loss: 1.9297
# Epoch 63/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9588 - loss: 0.1377 - val_accuracy: 0.7551 - val_loss: 1.9078
# Epoch 64/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9596 - loss: 0.1296 - val_accuracy: 0.7551 - val_loss: 1.9238
# Epoch 65/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9616 - loss: 0.1299 - val_accuracy: 0.7446 - val_loss: 1.9738
# Epoch 66/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9620 - loss: 0.1211 - val_accuracy: 0.7501 - val_loss: 1.9768
# Epoch 67/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9602 - loss: 0.1290 - val_accuracy: 0.7496 - val_loss: 2.0002
# Epoch 68/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9616 - loss: 0.1253 - val_accuracy: 0.7513 - val_loss: 1.9717
# Epoch 69/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9612 - loss: 0.1262 - val_accuracy: 0.7518 - val_loss: 2.0311
# Epoch 70/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9616 - loss: 0.1287 - val_accuracy: 0.7535 - val_loss: 2.0122
# Epoch 71/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9594 - loss: 0.1294 - val_accuracy: 0.7490 - val_loss: 1.9887
# Epoch 72/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9620 - loss: 0.1238 - val_accuracy: 0.7446 - val_loss: 2.0234
# Epoch 73/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9595 - loss: 0.1261 - val_accuracy: 0.7462 - val_loss: 2.0278
# Epoch 74/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9640 - loss: 0.1157 - val_accuracy: 0.7479 - val_loss: 2.0286
# Epoch 75/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9644 - loss: 0.1209 - val_accuracy: 0.7390 - val_loss: 2.0810
# Epoch 76/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9587 - loss: 0.1307 - val_accuracy: 0.7429 - val_loss: 2.0672
# Epoch 77/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9637 - loss: 0.1207 - val_accuracy: 0.7496 - val_loss: 2.0830
# Epoch 78/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9614 - loss: 0.1192 - val_accuracy: 0.7468 - val_loss: 2.0871
# Epoch 79/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9617 - loss: 0.1176 - val_accuracy: 0.7446 - val_loss: 2.1332
# Epoch 80/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9609 - loss: 0.1250 - val_accuracy: 0.7446 - val_loss: 2.1416
# Epoch 81/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9624 - loss: 0.1215 - val_accuracy: 0.7373 - val_loss: 2.1558
# Epoch 82/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9626 - loss: 0.1154 - val_accuracy: 0.7529 - val_loss: 2.1564
# Epoch 83/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9630 - loss: 0.1161 - val_accuracy: 0.7474 - val_loss: 2.2176
# Epoch 84/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9644 - loss: 0.1149 - val_accuracy: 0.7440 - val_loss: 2.1956
# Epoch 85/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9633 - loss: 0.1150 - val_accuracy: 0.7529 - val_loss: 2.1300
# Epoch 86/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9612 - loss: 0.1142 - val_accuracy: 0.7479 - val_loss: 2.2270
# Epoch 87/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9620 - loss: 0.1131 - val_accuracy: 0.7362 - val_loss: 2.2879
# Epoch 88/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9612 - loss: 0.1146 - val_accuracy: 0.7329 - val_loss: 2.2620
# Epoch 89/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9614 - loss: 0.1116 - val_accuracy: 0.7451 - val_loss: 2.2398
# Epoch 90/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9633 - loss: 0.1107 - val_accuracy: 0.7407 - val_loss: 2.3255
# Epoch 91/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9649 - loss: 0.1033 - val_accuracy: 0.7468 - val_loss: 2.2713
# Epoch 92/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9603 - loss: 0.1122 - val_accuracy: 0.7373 - val_loss: 2.3038
# Epoch 93/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9646 - loss: 0.1077 - val_accuracy: 0.7407 - val_loss: 2.3456
# Epoch 94/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9617 - loss: 0.1135 - val_accuracy: 0.7396 - val_loss: 2.3329
# Epoch 95/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9623 - loss: 0.1107 - val_accuracy: 0.7457 - val_loss: 2.3664
# Epoch 96/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9640 - loss: 0.1099 - val_accuracy: 0.7379 - val_loss: 2.3992
# Epoch 97/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9640 - loss: 0.1005 - val_accuracy: 0.7318 - val_loss: 2.4338
# Epoch 98/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9644 - loss: 0.1067 - val_accuracy: 0.7429 - val_loss: 2.3664
# Epoch 99/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9601 - loss: 0.1109 - val_accuracy: 0.7423 - val_loss: 2.4117
# Epoch 100/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9635 - loss: 0.1013 - val_accuracy: 0.7385 - val_loss: 2.3863
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7413 - loss: 2.4296
# Test Accuracy: 0.7413
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %% [markdown]
# ***Plot the results - train accuracy vs test accuracy and train loss vs. test loss***

# %%
import matplotlib.pyplot as plt

#accuracy plot
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

#loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ***Attempt embedding and multiple convolution layers***

# %%
#build tuned CNN model
cnn_model2 = Sequential([
    Embedding(input_dim=15000, output_dim=128),
    Conv1D(filters=128, kernel_size=5, activation='relu'),
    Conv1D(filters=128, kernel_size=5, activation='relu'),
    GlobalMaxPooling1D(),
    Dropout(0.4),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ***Compile the model, use Early Stopping to reduce fitting time if not gaining any additional accuracy***

# %%
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping

#compile with lower learning rate
cnn_model2.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

#early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

#train the model, increase epochs to 100 as Early Stopping is defined
history2 = cnn_model2.fit(
    x_train, y_train_cnn,
    epochs=100,
    batch_size=128,
    validation_split=0.2,
    callbacks=[early_stop],
    class_weight=class_weightings
)

#Evaluate the model
test_loss, test_acc = cnn_model2.evaluate(x_test, y_test_cnn)
print(f"Test Accuracy: {test_acc:.4f}")

y_pred_cnn2 = cnn_model2.predict(x_test)
y_pred_cnn2 = y_pred_cnn2.argmax(axis=1)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.2838 - loss: 3.6610 - val_accuracy: 0.3450 - val_loss: 2.9882
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.3489 - loss: 2.8563 - val_accuracy: 0.3450 - val_loss: 2.5064
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.3610 - loss: 2.7011 - val_accuracy: 0.3450 - val_loss: 2.3306
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.4354 - loss: 2.4780 - val_accuracy: 0.4942 - val_loss: 2.1082
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5022 - loss: 2.3337 - val_accuracy: 0.5019 - val_loss: 2.0350
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5079 - loss: 2.2691 - val_accuracy: 0.5125 - val_loss: 1.9698
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5123 - loss: 2.1987 - val_accuracy: 0.5131 - val_loss: 1.9109
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5197 - loss: 2.1430 - val_accuracy: 0.5192 - val_loss: 1.8625
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5264 - loss: 2.0880 - val_accuracy: 0.5209 - val_loss: 1.8085
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5420 - loss: 2.0272 - val_accuracy: 0.5337 - val_loss: 1.7551
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5576 - loss: 1.9659 - val_accuracy: 0.5637 - val_loss: 1.7041
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5862 - loss: 1.9148 - val_accuracy: 0.5765 - val_loss: 1.6642
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6017 - loss: 1.8641 - val_accuracy: 0.6004 - val_loss: 1.6337
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6142 - loss: 1.8191 - val_accuracy: 0.6032 - val_loss: 1.6038
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6263 - loss: 1.7779 - val_accuracy: 0.6155 - val_loss: 1.5767
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6351 - loss: 1.7446 - val_accuracy: 0.6138 - val_loss: 1.5548
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6420 - loss: 1.6992 - val_accuracy: 0.6255 - val_loss: 1.5322
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6505 - loss: 1.6533 - val_accuracy: 0.6327 - val_loss: 1.5113
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6612 - loss: 1.6176 - val_accuracy: 0.6377 - val_loss: 1.4957
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6695 - loss: 1.5819 - val_accuracy: 0.6427 - val_loss: 1.4762
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6806 - loss: 1.5392 - val_accuracy: 0.6500 - val_loss: 1.4613
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.6867 - loss: 1.4995 - val_accuracy: 0.6594 - val_loss: 1.4420
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.6931 - loss: 1.4638 - val_accuracy: 0.6644 - val_loss: 1.4268
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7093 - loss: 1.4144 - val_accuracy: 0.6605 - val_loss: 1.4157
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7145 - loss: 1.3768 - val_accuracy: 0.6756 - val_loss: 1.3992
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7221 - loss: 1.3352 - val_accuracy: 0.6784 - val_loss: 1.3896
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7290 - loss: 1.3052 - val_accuracy: 0.6806 - val_loss: 1.3798
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7357 - loss: 1.2647 - val_accuracy: 0.6795 - val_loss: 1.3825
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7464 - loss: 1.2254 - val_accuracy: 0.6889 - val_loss: 1.3744
# Epoch 30/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7562 - loss: 1.1889 - val_accuracy: 0.6906 - val_loss: 1.3772
# Epoch 31/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7571 - loss: 1.1596 - val_accuracy: 0.6962 - val_loss: 1.3832
# Epoch 32/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7655 - loss: 1.1228 - val_accuracy: 0.6962 - val_loss: 1.3857
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6754 - loss: 1.4095
# Test Accuracy: 0.6754
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %% [markdown]
# ***Plot the results after using extra convoluting layers and early stopping***

# %%
#plot training curves
plt.figure(figsize=(10, 4))

#accuracy
plt.subplot(1, 2, 1)
plt.plot(history2.history['accuracy'], label='Train Accuracy')
plt.plot(history2.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

#loss
plt.subplot(1, 2, 2)
plt.plot(history2.history['loss'], label='Train Loss')
plt.plot(history2.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Phase 3: Now create a CNN architecture with multiple filter sizes and richer feature extraction** #

# %%
# Number of words should match input dimensions
num_words = 15000

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Concatenate

input_layer = Input(shape=(maxlen,))
embedding = Embedding(input_dim=15000, output_dim=128)(input_layer)

branch_ksize3 = Conv1D(filters=128, kernel_size=3, activation='relu')(embedding)
branch_ksize3 = GlobalMaxPooling1D()(branch_ksize3)

branch_ksize4 = Conv1D(filters=128, kernel_size=4, activation='relu')(embedding)
branch_ksize4 = GlobalMaxPooling1D()(branch_ksize4)

branch_ksize5 = Conv1D(filters=128, kernel_size=5, activation='relu')(embedding)
branch_ksize5 = GlobalMaxPooling1D()(branch_ksize5)

merged_branches = Concatenate()([branch_ksize3, branch_ksize4, branch_ksize5])
merged_branches = Dropout(0.27)(merged_branches)
merged_branches = Dense(128, activation='relu')(merged_branches)
output = Dense(num_classes, activation='softmax')(merged_branches)

cnn_model3 = Model(inputs=input_layer, outputs=output)

# Compile
cnn_model3.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0004),
    metrics=['accuracy']
)

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model
history3 = cnn_model3.fit(
    x_train, y_train_cnn,
    epochs=100,
    batch_size=128,
    validation_split=0.2,
    class_weight=class_weightings,
    callbacks=[early_stop]
)

test_loss, test_acc = cnn_model3.evaluate(x_test, y_test_cnn)
print(f"Test Accuracy: {test_acc:.4f}")

y_pred_cnn3 = cnn_model3.predict(x_test)
y_pred_cnn3 = y_pred_cnn3.argmax(axis=1)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.3780 - loss: 2.9035 - val_accuracy: 0.4930 - val_loss: 2.0488
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.5010 - loss: 2.2004 - val_accuracy: 0.4981 - val_loss: 1.8848
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.5635 - loss: 2.0106 - val_accuracy: 0.6138 - val_loss: 1.6493
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.6636 - loss: 1.7367 - val_accuracy: 0.6845 - val_loss: 1.3906
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7051 - loss: 1.5125 - val_accuracy: 0.7173 - val_loss: 1.2460
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7333 - loss: 1.3442 - val_accuracy: 0.7301 - val_loss: 1.1717
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7624 - loss: 1.2176 - val_accuracy: 0.7546 - val_loss: 1.0924
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.7893 - loss: 1.0958 - val_accuracy: 0.7652 - val_loss: 1.0320
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.8148 - loss: 0.9752 - val_accuracy: 0.7741 - val_loss: 0.9779
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.8319 - loss: 0.8682 - val_accuracy: 0.7874 - val_loss: 0.9354
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.8505 - loss: 0.7663 - val_accuracy: 0.7941 - val_loss: 0.9096
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.8628 - loss: 0.6795 - val_accuracy: 0.8086 - val_loss: 0.8757
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.8849 - loss: 0.5900 - val_accuracy: 0.8091 - val_loss: 0.8521
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.8967 - loss: 0.5167 - val_accuracy: 0.8114 - val_loss: 0.8549
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9134 - loss: 0.4489 - val_accuracy: 0.8125 - val_loss: 0.8377
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9267 - loss: 0.3864 - val_accuracy: 0.8152 - val_loss: 0.8417
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9350 - loss: 0.3274 - val_accuracy: 0.8119 - val_loss: 0.8502
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9421 - loss: 0.2921 - val_accuracy: 0.8152 - val_loss: 0.8492
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7961 - loss: 0.8675
# Test Accuracy: 0.7961
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step

# %%
# plot training curves
plt.figure(figsize=(10, 4))

#accuracy
plt.subplot(1, 2, 1)
plt.plot(history3.history['accuracy'], label='Train Accuracy')
plt.plot(history3.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

#loss
plt.subplot(1, 2, 2)
plt.plot(history3.history['loss'], label='Train Loss')
plt.plot(history3.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Phase 4: Using tuned CNN with GLoVe, allowing the model to focus on classification instead of also needing to learn word interpretations from scratch** #

# %%
#num_words and maxlen already defined during SVM training

tokenizer = Tokenizer(num_words=num_words, oov_token="<UNK>") #<UNK> is a 'catch-all'
tokenizer.fit_on_texts(X_train_text) # build an internal vocabulary

# Make sequences for train and test sets
X_train_seq = tokenizer.texts_to_sequences(X_train_text)
X_test_seq = tokenizer.texts_to_sequences(X_test_text)

# pad them so each entry is the same length
X_train_pad = pad_sequences(X_train_seq, maxlen=maxlen)
X_test_pad = pad_sequences(X_test_seq, maxlen=maxlen)

# %% [markdown]
# ***Gensim allows loading of the GLoVe vector file through an API instead of needing to download it***

# %%
# Needed if Gensim module not installed
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 18.4 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import gensim.downloader as api
word_vectors = api.load("glove-wiki-gigaword-100")
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %% [markdown]
# ***Build the GloVe embedding matrix***

# %%
embedding_dim = 100
embedding_matrix = {}

vocab_size = min(num_words, len(tokenizer.word_index) + 1)
embedding_matrix = np.zeros((vocab_size, embedding_dim))

for word, i in tokenizer.word_index.items():
    if i >= vocab_size:
        continue
    if word in word_vectors:
      embedding_vector = word_vectors[word]
    else:
      embedding_vector = None
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# ***Build the CNN model using the GLoVe file in the Embedding layer***

# %%
input_layer = Input(shape=(maxlen,)) #define the input

# Apply the embedding layer
embedding = Embedding(
    input_dim=vocab_size,
    output_dim=embedding_dim,
    weights=[embedding_matrix],
    trainable=False
)

# Set up embedding layer as a Tensor, as needed for the CNN branches
embedding_GLoVe = embedding(input_layer)

branch_ksize3 = Conv1D(filters=128, kernel_size=3, activation='relu')(embedding_GLoVe)
branch_ksize3 = GlobalMaxPooling1D()(branch_ksize3)

branch_ksize4 = Conv1D(filters=128, kernel_size=4, activation='relu')(embedding_GLoVe)
branch_ksize4 = GlobalMaxPooling1D()(branch_ksize4)

branch_ksize5 = Conv1D(filters=128, kernel_size=5, activation='relu')(embedding_GLoVe)
branch_ksize5 = GlobalMaxPooling1D()(branch_ksize5)

merged_branches = Concatenate()([branch_ksize3, branch_ksize4, branch_ksize5])
merged_branches = Dropout(0.27)(merged_branches)
merged_branches = Dense(128, activation='relu')(merged_branches)
output = Dense(num_classes, activation='softmax')(merged_branches)

cnn_model4 = Model(inputs=input_layer, outputs=output)

# Compile
cnn_model4.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0004),
    metrics=['accuracy']
)

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model
history4 = cnn_model4.fit(
    x_train, y_train_cnn,
    epochs=100,
    batch_size=128,
    validation_split=0.2,
    class_weight=class_weightings,
    callbacks=[early_stop]
)

test_loss, test_acc = cnn_model4.evaluate(x_test, y_test_cnn)
print(f"Test Accuracy: {test_acc:.4f}")

y_pred_cnn4 = cnn_model4.predict(x_test)
y_pred_cnn4 = y_pred_cnn4.argmax(axis=1)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 91ms/step - accuracy: 0.3539 - loss: 2.9076 - val_accuracy: 0.4046 - val_loss: 2.1488
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4650 - loss: 2.3629 - val_accuracy: 0.4947 - val_loss: 1.9477
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5109 - loss: 2.1902 - val_accuracy: 0.5370 - val_loss: 1.8285
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5470 - loss: 2.0323 - val_accuracy: 0.5921 - val_loss: 1.7114
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5791 - loss: 1.9031 - val_accuracy: 0.6055 - val_loss: 1.6286
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6045 - loss: 1.7865 - val_accuracy: 0.6299 - val_loss: 1.5621
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6413 - loss: 1.6556 - val_accuracy: 0.6561 - val_loss: 1.4877
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6651 - loss: 1.5610 - val_accuracy: 0.6594 - val_loss: 1.4329
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6849 - loss: 1.4517 - val_accuracy: 0.6850 - val_loss: 1.3861
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7020 - loss: 1.3694 - val_accuracy: 0.6789 - val_loss: 1.3514
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7264 - loss: 1.2811 - val_accuracy: 0.7034 - val_loss: 1.3080
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7470 - loss: 1.1884 - val_accuracy: 0.7156 - val_loss: 1.2656
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7659 - loss: 1.1115 - val_accuracy: 0.7218 - val_loss: 1.2398
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7819 - loss: 1.0266 - val_accuracy: 0.7184 - val_loss: 1.2133
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8031 - loss: 0.9510 - val_accuracy: 0.7312 - val_loss: 1.1793
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8100 - loss: 0.8961 - val_accuracy: 0.7034 - val_loss: 1.2216
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8196 - loss: 0.8394 - val_accuracy: 0.7346 - val_loss: 1.1427
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8401 - loss: 0.7620 - val_accuracy: 0.7423 - val_loss: 1.1202
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8480 - loss: 0.7062 - val_accuracy: 0.7440 - val_loss: 1.1105
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8626 - loss: 0.6535 - val_accuracy: 0.7401 - val_loss: 1.1120
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8733 - loss: 0.5943 - val_accuracy: 0.7479 - val_loss: 1.0955
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8806 - loss: 0.5618 - val_accuracy: 0.7568 - val_loss: 1.0742
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8864 - loss: 0.5068 - val_accuracy: 0.7507 - val_loss: 1.0722
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8998 - loss: 0.4685 - val_accuracy: 0.7507 - val_loss: 1.0801
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9024 - loss: 0.4390 - val_accuracy: 0.7468 - val_loss: 1.0696
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9063 - loss: 0.4173 - val_accuracy: 0.7574 - val_loss: 1.0738
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9123 - loss: 0.3930 - val_accuracy: 0.7535 - val_loss: 1.0764
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9254 - loss: 0.3531 - val_accuracy: 0.7513 - val_loss: 1.0838
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7458 - loss: 1.0936
# Test Accuracy: 0.7458
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %% [markdown]
# ***Plot the results***

# %%
# plot training curves
plt.figure(figsize=(10, 4))

#accuracy
plt.subplot(1, 2, 1)
plt.plot(history4.history['accuracy'], label='Train Accuracy')
plt.plot(history4.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

#loss
plt.subplot(1, 2, 2)
plt.plot(history4.history['loss'], label='Train Loss')
plt.plot(history4.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Compare the results of the tuned SVM model and all CNN models** #

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
# Combine the results into a list
list_of_model_results = {
    "SVM": (y_test, y_pred_svm),
    "CNN_1": (y_test_cnn, y_pred_cnn),
    "CNN_2": (y_test_cnn, y_pred_cnn2),
    "CNN_3": (y_test_cnn, y_pred_cnn3),
    "CNN_4": (y_test_cnn, y_pred_cnn4)
}

# Tabulate the results
results_array = []

for name, (y_true, y_pred) in list_of_model_results.items():

    # Convert one-hot encoded true labels back to class labels if needed
    if len(y_true.shape) > 1:
        y_true_classes = np.argmax(y_true, axis=1)
    else:
        y_true_classes = y_true

    # Convert predicted probabilities back to class labels if needed
    if len(y_pred.shape) > 1:
        y_pred_classes = np.argmax(y_pred, axis=1)
    else:
        y_pred_classes = y_pred

    results_array.append({
        "Model": name,
        "Accuracy": accuracy_score(y_true_classes, y_pred_classes),
        "Precision": precision_score(y_true_classes, y_pred_classes, average='weighted', zero_division=0),
        "Recall": recall_score(y_true_classes, y_pred_classes, average='weighted', zero_division=0),
        "F1 Score": f1_score(y_true_classes, y_pred_classes, average='weighted', zero_division=0),
        "F1 Macro Score": f1_score(y_true_classes, y_pred_classes, average='macro', zero_division=0)
    })

df_results = pd.DataFrame(results_array)
print(df_results)
# Out:
#    Model  Accuracy  Precision    Recall  F1 Score  F1 Macro Score
# 0    SVM  0.830810   0.838305  0.830810  0.831235        0.695465
# 1  CNN_1  0.741318   0.729954  0.741318  0.728144        0.518848
# 2  CNN_2  0.675423   0.614091  0.675423  0.627760        0.112315
# 3  CNN_3  0.796082   0.784555  0.796082  0.783526        0.537229
# 4  CNN_4  0.745770   0.727348  0.745770  0.723582        0.448178

# %% [markdown]
# # **Dump files** #

# %%
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (1.5.3)

# %%
# SVM
import joblib
joblib.dump(svm_model, f"{MODELS_PATH}/svm_model.pkl")
joblib.dump(vector, f"{MODELS_PATH}/tfidf_vectorizer.pkl")

# CNN
cnn_model.save(f"{MODELS_PATH}/cnn_model.keras")
joblib.dump(tokenizer, f"{MODELS_PATH}/tokenizer.pkl")
joblib.dump(maxlen, f"{MODELS_PATH}/maxlen.pkl")
# Out:
# ['/content/drive/MyDrive/reuters_text_classification/models/maxlen.pkl']

# %% [markdown]
# # **Use Gradio to add ability for text entry and model predictions** #

# %%
pip install --upgrade gradio
# Out:
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (5.50.0)
# Collecting gradio
#   Downloading gradio-6.12.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.13.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.135.3)
# Collecting gradio-client==2.4.1 (from gradio)
#   Downloading gradio_client-2.4.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.2)
# Collecting hf-gradio<1.0,>=0.3.0 (from gradio)
#   Downloading hf_gradio-0.4.1-py3-none-any.whl.metadata (428 bytes)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.10.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.11.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio) (26.0)
# Requirement already satisfied: pandas<4.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<13.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.12.3)
# Requirement already satisfied: pydub<1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart<1.0,>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.0.26)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.12/dist-packages (from gradio) (2025.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (6.0.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<2.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.52.1)
# Requirement already satisfied: tomlkit<0.15.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.24.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.44.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==2.4.1->gradio) (2025.3.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.25.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.4.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=1.0->gradio) (2026.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<=3.0,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<=3.0,>=2.0->gradio) (2.41.4)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading gradio-6.12.0-py3-none-any.whl (19.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.6/19.6 MB 67.1 MB/s eta 0:00:00
# Downloading gradio_client-2.4.1-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 6.3 MB/s eta 0:00:00
# Downloading hf_gradio-0.4.1-py3-none-any.whl (4.5 kB)
# Installing collected packages: gradio-client, hf-gradio, gradio
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 1.14.0
#     Uninstalling gradio_client-1.14.0:
#       Successfully uninstalled gradio_client-1.14.0
#   Attempting uninstall: gradio
#     Found existing installation: gradio 5.50.0
#     Uninstalling gradio-5.50.0:
#       Successfully uninstalled gradio-5.50.0
# Successfully installed gradio-6.12.0 gradio-client-2.4.1 hf-gradio-0.4.1
