# %% [markdown]
# # **Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
BASE_PATH = "/content/drive/MyDrive/reuters_text_classification"
MODELS_PATH = f"{BASE_PATH}/models"
NOTEBOOKS_PATH = f"{BASE_PATH}/notebooks"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Data download and preprocessing** #

# %% [markdown]
# ***Download and split the data***

# %%
from tensorflow.keras.datasets import reuters
from sklearn.model_selection import train_test_split
import numpy as np

# Load dataset with an 80/20 split between training and testing
(X_train, y_train), (X_test, y_test) = reuters.load_data(test_split=0.2)

# See the first few rows of X_train and y_train to verify the download worked
print(X_train[:3])
print('\n',y_train[:3])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# [list([1, 27595, 28842, 8, 43, 10, 447, 5, 25, 207, 270, 5, 3095, 111, 16, 369, 186, 90, 67, 7, 89, 5, 19, 102, 6, 19, 124, 15, 90, 67, 84, 22, 482, 26, 7, 48, 4, 49, 8, 864, 39, 209, 154, 6, 151, 6, 83, 11, 15, 22, 155, 11, 15, 7, 48, 9, 4579, 1005, 504, 6, 258, 6, 272, 11, 15, 22, 134, 44, 11, 15, 16, 8, 197, 1245, 90, 67, 52, 29, 209, 30, 32, 132, 6, 109, 15, 17, 12])
#  list([1, 3267, 699, 3434, 2295, 56, 16784, 7511, 9, 56, 3906, 1073, 81, 5, 1198, 57, 366, 737, 132, 20, 4093, 7, 19261, 49, 2295, 13415, 1037, 3267, 699, 3434, 8, 7, 10, 241, 16, 855, 129, 231, 783, 5, 4, 587, 2295, 13415, 30625, 775, 7, 48, 34, 191, 44, 35, 1795, 505, 17, 12])
#  list([1, 53, 12, 284, 15, 14, 272, 26, 53, 959, 32, 818, 15, 14, 272, 26, 39, 684, 70, 11, 14, 12, 3886, 18, 180, 183, 187, 70, 11, 14, 102, 32, 11, 29, 53, 44, 704, 15, 14, 19, 758, 15, 53, 959, 47, 1013, 15, 14, 19, 132, 15, 39, 965, 32, 11, 14, 147, 72, 11, 180, 183, 187, 44, 11, 14, 102, 19, 11, 123, 186, 90, 67, 960, 4, 78, 13, 68, 467, 511, 110, 59, 89, 90, 67, 1390, 55, 2678, 92, 617, 80, 1274, 46, 905, 220, 13, 4, 346, 48, 235, 629, 5, 211, 5, 1118, 7, 11733, 81, 5, 187, 11, 15, 9, 1709, 201, 5, 47, 3615, 18, 478, 4514, 5, 1118, 7, 232, 13051, 71, 5, 160, 63, 11, 9, 26503, 81, 5, 102, 59, 11, 17, 12])]
#
#  [3 4 3]

# %% [markdown]
# ***Translate integers to words***

# %%
# Get the word-to-index mapping
word_index = reuters.get_word_index()

# Flip it so it becomes an index-to-word mapping
text_index = {value: key for key, value in word_index.items()}

# Test if it works
print(text_index[27595])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters_word_index.json
# 550378/550378 ━━━━━━━━━━━━━━━━━━━━ 1s 1us/step
# wattie

# %% [markdown]
# ***Vectorize the training dataset***

# %%
# Array will hold the decoded text for X_train
X_train_text = []

# Decode training data from integer into text
for index_word_pair in X_train:
    X_train_word_array = []
    for this_word in index_word_pair:
        current_word = text_index.get(this_word - 3, '?')
        X_train_word_array.append(current_word)
    current_sentence = ' '.join(X_train_word_array)
    X_train_text.append(current_sentence)

# %% [markdown]
# ***Vectorize the testing dataset***

# %%
# Array will hold the decoded text for X_test
X_test_text = []

# Decode test data
for index_word_pair in X_test:
    X_test_word_array = []
    for this_word in index_word_pair:
        current_word = text_index.get(this_word - 3, '?')
        X_test_word_array.append(current_word)
    X_test_sentence = ' '.join(X_test_word_array)
    X_test_text.append(X_test_sentence)

# %% [markdown]
# ***Convert text to TF-IDF vectors for SVM model***

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import TfidfVectorizer as tfidf

# Convert text
vector = tfidf(max_features=None,  # Let min_df/max_df decide
               min_df=5,
               max_df=0.9)
X_train_vector = vector.fit_transform(X_train_text)
X_test_vector = vector.transform(X_test_text)
print(len(vector.vocabulary_))
# Out:
# 9101

# %% [markdown]
# # **Phase 1: SVM model**

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report, accuracy_score

# Choose C=1 as an initial C
svm_model = LinearSVC(C=1,
                      class_weight = 'balanced')
svm_model.fit(X_train_vector, y_train)

# Perform initial predictions and evaluate results
y_pred_svm = svm_model.predict(X_test_vector)
print(f"Accuracy: {accuracy_score(y_test, y_pred_svm)}")
print(f"Classification report:\n{classification_report(y_test, y_pred_svm)}")
# Out:
# Accuracy: 0.8308103294746215
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.76      0.77      0.77       105
#            2       0.77      0.85      0.81        20
#            3       0.95      0.92      0.93       813
#            4       0.87      0.88      0.87       474
#            5       0.33      0.20      0.25         5
#            6       0.81      0.93      0.87        14
#            7       0.75      1.00      0.86         3
#            8       0.66      0.71      0.68        38
#            9       0.80      0.96      0.87        25
#           10       0.82      0.93      0.88        30
#           11       0.70      0.73      0.72        83
#           12       0.50      0.54      0.52        13
#           13       0.67      0.76      0.71        37
#           14       0.29      1.00      0.44         2
#           15       0.67      0.44      0.53         9
#           16       0.77      0.82      0.79        99
#           17       0.71      0.83      0.77        12
#           18       0.74      0.70      0.72        20
#           19       0.80      0.66      0.72       133
#           20       0.58      0.61      0.60        70
#           21       0.56      0.89      0.69        27
#           22       1.00      0.29      0.44         7
#           23       0.67      0.83      0.74        12
#           24       0.58      0.58      0.58        19
#           25       0.88      0.94      0.91        31
#           26       0.88      0.88      0.88         8
#           27       0.67      0.50      0.57         4
#           28       0.44      0.40      0.42        10
#           29       0.50      1.00      0.67         4
#           30       1.00      0.75      0.86        12
#           31       0.82      0.69      0.75        13
#           32       0.91      1.00      0.95        10
#           33       0.80      0.80      0.80         5
#           34       0.80      0.57      0.67         7
#           35       1.00      0.67      0.80         6
#           36       0.46      0.55      0.50        11
#           37       0.50      1.00      0.67         2
#           38       0.67      0.67      0.67         3
#           39       0.40      0.40      0.40         5
#           40       0.60      0.30      0.40        10
#           41       0.71      0.62      0.67         8
#           42       1.00      0.67      0.80         3
#           43       0.67      1.00      0.80         6
#           44       0.57      0.80      0.67         5
#           45       0.50      1.00      0.67         1
#
#     accuracy                           0.83      2246
#    macro avg       0.70      0.73      0.70      2246
# weighted avg       0.84      0.83      0.83      2246

# %% [markdown]
# ***Attempt to improve the model by tuning the hyperparamter C***

# %%
from sklearn.model_selection import cross_val_score

# Test different C values
c_values = [0.01, 0.1, 1.0, 10.0, 100.0]
best_C = None
best_score = 0

# Iterate over the 5 c_values
for test_c in c_values:

    # create a model based on test_c
    svm_model = LinearSVC(C=test_c)  #Linear is best for clean text

    # Score the model on 5-fold cross-validation. Use n_jobs=-1 for speed purposes
    result = cross_val_score(svm_model, X_train_vector, y_train, cv=5, scoring='accuracy', n_jobs=-1)

    # Average the resultant scores
    ave_result = np.mean(result)

    # Print the averaged accuracy and standard deviation
    print(f"C={test_c}: Mean CV Accuracy = {ave_result:.4f} (±{np.std(result):.4f})")

    # Hold the C value based on the best average mean score
    if ave_result > best_score:
        best_score = ave_result
        best_C = test_c

# Print best C
print("\nBest C value:", best_C)
print("Best mean CV accuracy:", best_score)
# Out:
# C=0.01: Mean CV Accuracy = 0.6899 (±0.0064)
# C=0.1: Mean CV Accuracy = 0.8308 (±0.0062)
# C=1.0: Mean CV Accuracy = 0.8408 (±0.0063)
# C=10.0: Mean CV Accuracy = 0.8199 (±0.0060)
# C=100.0: Mean CV Accuracy = 0.8100 (±0.0048)
#
# Best C value: 1.0
# Best mean CV accuracy: 0.8407933043565556

# %% [markdown]
# ***A C-value of 1 had the best accuracy (in my run). Further tuning by setting C-values between 1 and 10, inclusive***

# %%
c_values = range(1, 11)
best_C = None
best_score = 0

# Iterate over the 10 c_values
for test_c in c_values:
    # create a model based on test_c
    svm_model = LinearSVC(C=test_c)

    # Score the model on 5-fold cross-validation. Use n_jobs=-1 for speed purposes
    result = cross_val_score(svm_model, X_train_vector, y_train, cv=5, scoring='accuracy', n_jobs=-1)

    # Average the resultant scores
    ave_result = np.mean(result)

    # Print the averaged accuracy and standard deviation
    print(f"C={test_c}: Mean CV Accuracy = {ave_result:.4f} (±{np.std(result):.4f})")

    # Hold the C value based on the best average mean score
    if ave_result > best_score:
        best_score = ave_result
        best_C = test_c

# Print best C
print("\nBest C value:", best_C)
print("Best mean CV accuracy:", best_score)
# Out:
# C=1: Mean CV Accuracy = 0.8408 (±0.0063)
# C=2: Mean CV Accuracy = 0.8314 (±0.0069)
# C=3: Mean CV Accuracy = 0.8271 (±0.0060)
# C=4: Mean CV Accuracy = 0.8257 (±0.0057)
# C=5: Mean CV Accuracy = 0.8235 (±0.0054)
# C=6: Mean CV Accuracy = 0.8222 (±0.0050)
# C=7: Mean CV Accuracy = 0.8213 (±0.0056)
# C=8: Mean CV Accuracy = 0.8206 (±0.0056)
# C=9: Mean CV Accuracy = 0.8203 (±0.0059)
# C=10: Mean CV Accuracy = 0.8199 (±0.0060)
#
# Best C value: 1
# Best mean CV accuracy: 0.8407933043565556

# %% [markdown]
# ***Fit the model with the best C-value and display the accuracy***

# %%
# Choose C=1 as it was determined to be the best value
svm_model = LinearSVC(C=1,
                      class_weight = 'balanced')
svm_model = svm_model.fit(X_train_vector, y_train)

# Perform predictions and evaluate results
y_pred_svm = svm_model.predict(X_test_vector)
print(f"Accuracy: {accuracy_score(y_test, y_pred_svm):.3f}\n")
print(f"Classification report:\n{classification_report(y_test, y_pred_svm)}")
# Out:
# Accuracy: 0.831
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        12
#            1       0.76      0.77      0.77       105
#            2       0.77      0.85      0.81        20
#            3       0.95      0.92      0.93       813
#            4       0.87      0.88      0.87       474
#            5       0.33      0.20      0.25         5
#            6       0.81      0.93      0.87        14
#            7       0.75      1.00      0.86         3
#            8       0.66      0.71      0.68        38
#            9       0.80      0.96      0.87        25
#           10       0.82      0.93      0.88        30
#           11       0.70      0.73      0.72        83
#           12       0.50      0.54      0.52        13
#           13       0.67      0.76      0.71        37
#           14       0.29      1.00      0.44         2
#           15       0.67      0.44      0.53         9
#           16       0.77      0.82      0.79        99
#           17       0.71      0.83      0.77        12
#           18       0.74      0.70      0.72        20
#           19       0.80      0.66      0.72       133
#           20       0.58      0.61      0.60        70
#           21       0.56      0.89      0.69        27
#           22       1.00      0.29      0.44         7
#           23       0.67      0.83      0.74        12
#           24       0.58      0.58      0.58        19
#           25       0.88      0.94      0.91        31
#           26       0.88      0.88      0.88         8
#           27       0.67      0.50      0.57         4
#           28       0.44      0.40      0.42        10
#           29       0.50      1.00      0.67         4
#           30       1.00      0.75      0.86        12
#           31       0.82      0.69      0.75        13
#           32       0.91      1.00      0.95        10
#           33       0.80      0.80      0.80         5
#           34       0.80      0.57      0.67         7
#           35       1.00      0.67      0.80         6
#           36       0.46      0.55      0.50        11
#           37       0.50      1.00      0.67         2
#           38       0.67      0.67      0.67         3
#           39       0.40      0.40      0.40         5
#           40       0.60      0.30      0.40        10
#           41       0.71      0.62      0.67         8
#           42       1.00      0.67      0.80         3
#           43       0.67      1.00      0.80         6
#           44       0.57      0.80      0.67         5
#           45       0.50      1.00      0.67         1
#
#     accuracy                           0.83      2246
#    macro avg       0.70      0.73      0.70      2246
# weighted avg       0.84      0.83      0.83      2246

# %% [markdown]
# # **Phase 2: Build the CNN model using raw integer sequences**

# %% [markdown]
# ***This piece will help increase visibility of minor classes without pulling down weighting (much) of major classes***

# %%
def scaled_class_weights(base_dict, scale):
    return {cls: 1.0 + (w - 1.0) * scale for cls, w in base_dict.items()}

# %% [markdown]
# ***Load the data and build the training and test sets***

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
#load
(x_train, y_train), (x_test, y_test) = reuters.load_data(num_words=15000)

#pad sequence
maxlen = 300
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

#number of classes
num_classes = int(np.max(y_train) + 1)

# %% [markdown]
# ***Change the label values to categories by one-hot encoding***

# %%
from tensorflow.keras.utils import to_categorical
#oneHot Encode Labels
y_train_cnn = to_categorical(y_train, num_classes)
y_test_cnn = to_categorical(y_test, num_classes)

# %% [markdown]
# ***Create class weighting dictionary***

# %%
from sklearn.utils.class_weight import compute_class_weight

# y_train is one-hot encoded so convert back to class IDs
y_train_labels = np.argmax(y_train_cnn, axis=1)

# Load the class labels
classes = np.unique(y_train_labels)

# Compute the weights
weights = compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=y_train_labels
)

# Fill the dictionary
class_weight_dict = dict(zip(classes, weights))

# Retrieve and save the weightings.
class_weightings = scaled_class_weights(class_weight_dict, 0.1)

# %% [markdown]
# ***Import libraries and build the model***

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout

#build CNN Model
cnn_model = Sequential([
    Embedding(input_dim=15000, output_dim=128),
    Conv1D(filters=64, kernel_size=5, activation='relu'),
    GlobalMaxPooling1D(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ***Compile the model***

# %%
#complile the CNN model
cnn_model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %% [markdown]
# ***Train and evaluate the model***

# %%
history = cnn_model.fit(
    x_train, y_train_cnn,
    epochs=100, # no early stopping set yet
    batch_size=128,
    validation_split=0.2,
    class_weight=class_weightings
)

# Evaluate the results
test_loss, test_acc = cnn_model.evaluate(x_test, y_test_cnn)
print(f"Test Accuracy: {test_acc:.4f}")

# Save the predictions for later comparisons
y_pred_cnn = cnn_model.predict(x_test)
y_pred_cnn_classes = y_pred_cnn.argmax(axis=1)
y_true_cnn_classes = np.argmax(y_test_cnn, axis=1)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.3539 - loss: 2.8649 - val_accuracy: 0.4969 - val_loss: 1.9940
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5141 - loss: 2.1587 - val_accuracy: 0.5715 - val_loss: 1.7130
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5916 - loss: 1.9086 - val_accuracy: 0.6600 - val_loss: 1.5104
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6431 - loss: 1.7261 - val_accuracy: 0.6906 - val_loss: 1.3628
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6836 - loss: 1.5690 - val_accuracy: 0.7017 - val_loss: 1.2623
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7070 - loss: 1.4205 - val_accuracy: 0.7190 - val_loss: 1.1961
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7325 - loss: 1.2837 - val_accuracy: 0.7362 - val_loss: 1.1361
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7623 - loss: 1.1475 - val_accuracy: 0.7590 - val_loss: 1.0970
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7933 - loss: 1.0018 - val_accuracy: 0.7641 - val_loss: 1.0770
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8191 - loss: 0.8815 - val_accuracy: 0.7718 - val_loss: 1.0631
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8384 - loss: 0.7773 - val_accuracy: 0.7780 - val_loss: 1.0427
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8579 - loss: 0.6892 - val_accuracy: 0.7780 - val_loss: 1.0385
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8713 - loss: 0.6136 - val_accuracy: 0.7830 - val_loss: 1.0599
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8857 - loss: 0.5497 - val_accuracy: 0.7785 - val_loss: 1.0730
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8955 - loss: 0.4973 - val_accuracy: 0.7858 - val_loss: 1.0879
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9086 - loss: 0.4384 - val_accuracy: 0.7796 - val_loss: 1.1115
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9134 - loss: 0.4120 - val_accuracy: 0.7807 - val_loss: 1.1265
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9179 - loss: 0.3811 - val_accuracy: 0.7796 - val_loss: 1.1358
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9172 - loss: 0.3651 - val_accuracy: 0.7846 - val_loss: 1.1600
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9271 - loss: 0.3268 - val_accuracy: 0.7813 - val_loss: 1.2223
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9319 - loss: 0.3080 - val_accuracy: 0.7846 - val_loss: 1.2161
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9292 - loss: 0.3042 - val_accuracy: 0.7774 - val_loss: 1.2263
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9353 - loss: 0.2918 - val_accuracy: 0.7774 - val_loss: 1.2617
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9399 - loss: 0.2648 - val_accuracy: 0.7746 - val_loss: 1.2804
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9354 - loss: 0.2605 - val_accuracy: 0.7763 - val_loss: 1.3084
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9420 - loss: 0.2609 - val_accuracy: 0.7702 - val_loss: 1.3160
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9428 - loss: 0.2419 - val_accuracy: 0.7668 - val_loss: 1.3515
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9492 - loss: 0.2124 - val_accuracy: 0.7707 - val_loss: 1.3650
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9474 - loss: 0.2169 - val_accuracy: 0.7763 - val_loss: 1.4053
# Epoch 30/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9459 - loss: 0.2205 - val_accuracy: 0.7646 - val_loss: 1.4247
# Epoch 31/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9482 - loss: 0.2033 - val_accuracy: 0.7679 - val_loss: 1.4175
# Epoch 32/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9470 - loss: 0.2088 - val_accuracy: 0.7685 - val_loss: 1.4102
# Epoch 33/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9463 - loss: 0.2110 - val_accuracy: 0.7763 - val_loss: 1.4075
# Epoch 34/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9489 - loss: 0.1986 - val_accuracy: 0.7707 - val_loss: 1.4688
# Epoch 35/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9517 - loss: 0.1959 - val_accuracy: 0.7707 - val_loss: 1.4444
# Epoch 36/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9539 - loss: 0.1819 - val_accuracy: 0.7741 - val_loss: 1.4910
# Epoch 37/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9537 - loss: 0.1906 - val_accuracy: 0.7668 - val_loss: 1.5243
# Epoch 38/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9511 - loss: 0.1844 - val_accuracy: 0.7629 - val_loss: 1.5470
# Epoch 39/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9528 - loss: 0.1719 - val_accuracy: 0.7652 - val_loss: 1.5359
# Epoch 40/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9502 - loss: 0.1842 - val_accuracy: 0.7696 - val_loss: 1.5419
# Epoch 41/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9518 - loss: 0.1805 - val_accuracy: 0.7663 - val_loss: 1.5297
# Epoch 42/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9527 - loss: 0.1699 - val_accuracy: 0.7685 - val_loss: 1.5761
# Epoch 43/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9592 - loss: 0.1656 - val_accuracy: 0.7652 - val_loss: 1.5794
# Epoch 44/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9569 - loss: 0.1582 - val_accuracy: 0.7679 - val_loss: 1.6052
# Epoch 45/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9560 - loss: 0.1595 - val_accuracy: 0.7724 - val_loss: 1.6265
# Epoch 46/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9545 - loss: 0.1549 - val_accuracy: 0.7685 - val_loss: 1.6058
# Epoch 47/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9598 - loss: 0.1491 - val_accuracy: 0.7663 - val_loss: 1.6336
# Epoch 48/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9567 - loss: 0.1503 - val_accuracy: 0.7652 - val_loss: 1.6855
# Epoch 49/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9559 - loss: 0.1511 - val_accuracy: 0.7679 - val_loss: 1.6696
# Epoch 50/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9546 - loss: 0.1598 - val_accuracy: 0.7646 - val_loss: 1.7235
# Epoch 51/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9614 - loss: 0.1421 - val_accuracy: 0.7613 - val_loss: 1.7601
# Epoch 52/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9577 - loss: 0.1497 - val_accuracy: 0.7635 - val_loss: 1.7242
# Epoch 53/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9582 - loss: 0.1542 - val_accuracy: 0.7602 - val_loss: 1.7246
# Epoch 54/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9555 - loss: 0.1493 - val_accuracy: 0.7613 - val_loss: 1.7312
# Epoch 55/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9595 - loss: 0.1448 - val_accuracy: 0.7607 - val_loss: 1.7630
# Epoch 56/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9620 - loss: 0.1301 - val_accuracy: 0.7574 - val_loss: 1.8088
# Epoch 57/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9595 - loss: 0.1244 - val_accuracy: 0.7568 - val_loss: 1.8046
# Epoch 58/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9578 - loss: 0.1407 - val_accuracy: 0.7540 - val_loss: 1.8307
# Epoch 59/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9602 - loss: 0.1403 - val_accuracy: 0.7540 - val_loss: 1.8271
# Epoch 60/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9553 - loss: 0.1435 - val_accuracy: 0.7579 - val_loss: 1.8169
# Epoch 61/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9589 - loss: 0.1310 - val_accuracy: 0.7607 - val_loss: 1.8122
# Epoch 62/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9585 - loss: 0.1349 - val_accuracy: 0.7596 - val_loss: 1.8588
# Epoch 63/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9609 - loss: 0.1271 - val_accuracy: 0.7641 - val_loss: 1.9234
# Epoch 64/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9563 - loss: 0.1417 - val_accuracy: 0.7635 - val_loss: 1.8380
# Epoch 65/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9566 - loss: 0.1375 - val_accuracy: 0.7624 - val_loss: 1.9046
# Epoch 66/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9581 - loss: 0.1418 - val_accuracy: 0.7602 - val_loss: 1.8419
# Epoch 67/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9592 - loss: 0.1294 - val_accuracy: 0.7596 - val_loss: 1.9068
# Epoch 68/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9631 - loss: 0.1251 - val_accuracy: 0.7574 - val_loss: 1.9559
# Epoch 69/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9638 - loss: 0.1201 - val_accuracy: 0.7585 - val_loss: 1.9060
# Epoch 70/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9612 - loss: 0.1259 - val_accuracy: 0.7563 - val_loss: 1.9593
# Epoch 71/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9610 - loss: 0.1197 - val_accuracy: 0.7579 - val_loss: 1.9785
# Epoch 72/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9635 - loss: 0.1188 - val_accuracy: 0.7513 - val_loss: 1.9879
# Epoch 73/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9603 - loss: 0.1193 - val_accuracy: 0.7563 - val_loss: 1.9598
# Epoch 74/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9595 - loss: 0.1220 - val_accuracy: 0.7574 - val_loss: 1.9721
# Epoch 75/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9619 - loss: 0.1185 - val_accuracy: 0.7518 - val_loss: 2.0660
# Epoch 76/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9617 - loss: 0.1125 - val_accuracy: 0.7563 - val_loss: 1.9921
# Epoch 77/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9612 - loss: 0.1144 - val_accuracy: 0.7490 - val_loss: 2.0655
# Epoch 78/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9626 - loss: 0.1187 - val_accuracy: 0.7540 - val_loss: 2.0153
# Epoch 79/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9644 - loss: 0.1098 - val_accuracy: 0.7546 - val_loss: 2.0790
# Epoch 80/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9616 - loss: 0.1148 - val_accuracy: 0.7457 - val_loss: 2.1082
# Epoch 81/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9613 - loss: 0.1156 - val_accuracy: 0.7507 - val_loss: 2.0637
# Epoch 82/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9640 - loss: 0.1119 - val_accuracy: 0.7535 - val_loss: 2.0917
# Epoch 83/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9634 - loss: 0.1087 - val_accuracy: 0.7524 - val_loss: 2.0766
# Epoch 84/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9582 - loss: 0.1163 - val_accuracy: 0.7568 - val_loss: 2.1050
# Epoch 85/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9612 - loss: 0.1176 - val_accuracy: 0.7563 - val_loss: 2.1155
# Epoch 86/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9633 - loss: 0.1041 - val_accuracy: 0.7468 - val_loss: 2.1867
# Epoch 87/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9616 - loss: 0.1139 - val_accuracy: 0.7490 - val_loss: 2.1298
# Epoch 88/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9605 - loss: 0.1168 - val_accuracy: 0.7513 - val_loss: 2.1930
# Epoch 89/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9620 - loss: 0.1073 - val_accuracy: 0.7546 - val_loss: 2.2049
# Epoch 90/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9617 - loss: 0.1154 - val_accuracy: 0.7462 - val_loss: 2.1765
# Epoch 91/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9608 - loss: 0.1148 - val_accuracy: 0.7529 - val_loss: 2.1431
# Epoch 92/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9610 - loss: 0.1147 - val_accuracy: 0.7457 - val_loss: 2.2129
# Epoch 93/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9641 - loss: 0.1037 - val_accuracy: 0.7513 - val_loss: 2.2664
# Epoch 94/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9621 - loss: 0.1124 - val_accuracy: 0.7446 - val_loss: 2.2725
# Epoch 95/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9612 - loss: 0.1177 - val_accuracy: 0.7446 - val_loss: 2.2330
# Epoch 96/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9599 - loss: 0.1106 - val_accuracy: 0.7440 - val_loss: 2.2499
# Epoch 97/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9637 - loss: 0.1065 - val_accuracy: 0.7479 - val_loss: 2.2142
# Epoch 98/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9634 - loss: 0.1030 - val_accuracy: 0.7501 - val_loss: 2.2990
# Epoch 99/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9640 - loss: 0.0963 - val_accuracy: 0.7457 - val_loss: 2.3182
# Epoch 100/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9630 - loss: 0.1029 - val_accuracy: 0.7429 - val_loss: 2.3214
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7556 - loss: 2.3488
# Test Accuracy: 0.7556
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %% [markdown]
# ***Plot the results - train accuracy vs test accuracy and train loss vs. test loss***

# %%
import matplotlib.pyplot as plt

#accuracy plot
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

#loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ***Attempt embedding and multiple convolution layers***

# %%
#build tuned CNN model
cnn_model2 = Sequential([
    Embedding(input_dim=15000, output_dim=128),
    Conv1D(filters=128, kernel_size=5, activation='relu'),
    Conv1D(filters=128, kernel_size=5, activation='relu'),
    GlobalMaxPooling1D(),
    Dropout(0.4),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ***Compile the model, use Early Stopping to reduce fitting time if not gaining any additional accuracy***

# %%
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping

#compile with lower learning rate
cnn_model2.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

#early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

#train the model, increase epochs to 100 as Early Stopping is defined
history2 = cnn_model2.fit(
    x_train, y_train_cnn,
    epochs=100,
    batch_size=128,
    validation_split=0.2,
    callbacks=[early_stop],
    class_weight=class_weightings
)

#Evaluate the model
test_loss, test_acc = cnn_model2.evaluate(x_test, y_test_cnn)
print(f"Test Accuracy: {test_acc:.4f}")

y_pred_cnn2 = cnn_model2.predict(x_test)
y_pred_cnn2 = y_pred_cnn2.argmax(axis=1)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.2728 - loss: 3.5992 - val_accuracy: 0.3450 - val_loss: 2.7545
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.3491 - loss: 2.7838 - val_accuracy: 0.3450 - val_loss: 2.4536
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.3691 - loss: 2.6691 - val_accuracy: 0.3556 - val_loss: 2.3526
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4445 - loss: 2.4839 - val_accuracy: 0.4914 - val_loss: 2.0932
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4971 - loss: 2.3175 - val_accuracy: 0.4964 - val_loss: 2.0198
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5070 - loss: 2.2555 - val_accuracy: 0.5097 - val_loss: 1.9676
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5140 - loss: 2.2018 - val_accuracy: 0.5142 - val_loss: 1.9084
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5244 - loss: 2.1430 - val_accuracy: 0.5198 - val_loss: 1.8582
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5258 - loss: 2.0940 - val_accuracy: 0.5253 - val_loss: 1.8197
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5331 - loss: 2.0434 - val_accuracy: 0.5287 - val_loss: 1.7711
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5427 - loss: 1.9932 - val_accuracy: 0.5326 - val_loss: 1.7310
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5496 - loss: 1.9475 - val_accuracy: 0.5526 - val_loss: 1.7055
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5740 - loss: 1.9071 - val_accuracy: 0.5632 - val_loss: 1.6760
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5855 - loss: 1.8689 - val_accuracy: 0.5776 - val_loss: 1.6487
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6008 - loss: 1.8293 - val_accuracy: 0.5888 - val_loss: 1.6174
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6182 - loss: 1.7926 - val_accuracy: 0.6016 - val_loss: 1.5937
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6221 - loss: 1.7535 - val_accuracy: 0.6016 - val_loss: 1.5775
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6330 - loss: 1.7219 - val_accuracy: 0.6121 - val_loss: 1.5513
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6415 - loss: 1.6778 - val_accuracy: 0.6166 - val_loss: 1.5290
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6472 - loss: 1.6398 - val_accuracy: 0.6299 - val_loss: 1.5004
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6614 - loss: 1.5894 - val_accuracy: 0.6366 - val_loss: 1.4783
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6686 - loss: 1.5557 - val_accuracy: 0.6511 - val_loss: 1.4580
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6772 - loss: 1.5061 - val_accuracy: 0.6539 - val_loss: 1.4380
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6932 - loss: 1.4633 - val_accuracy: 0.6594 - val_loss: 1.4182
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7024 - loss: 1.4220 - val_accuracy: 0.6628 - val_loss: 1.4059
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7105 - loss: 1.3799 - val_accuracy: 0.6622 - val_loss: 1.3990
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7138 - loss: 1.3411 - val_accuracy: 0.6667 - val_loss: 1.3863
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7184 - loss: 1.3018 - val_accuracy: 0.6706 - val_loss: 1.3867
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7286 - loss: 1.2616 - val_accuracy: 0.6717 - val_loss: 1.3787
# Epoch 30/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7332 - loss: 1.2330 - val_accuracy: 0.6733 - val_loss: 1.3831
# Epoch 31/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7418 - loss: 1.1821 - val_accuracy: 0.6795 - val_loss: 1.3913
# Epoch 32/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7527 - loss: 1.1526 - val_accuracy: 0.6850 - val_loss: 1.3925
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6696 - loss: 1.4115
# Test Accuracy: 0.6696
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %% [markdown]
# ***Plot the results after using extra convoluting layers and early stopping***

# %%
#plot training curves
plt.figure(figsize=(10, 4))

#accuracy
plt.subplot(1, 2, 1)
plt.plot(history2.history['accuracy'], label='Train Accuracy')
plt.plot(history2.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

#loss
plt.subplot(1, 2, 2)
plt.plot(history2.history['loss'], label='Train Loss')
plt.plot(history2.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Phase 3: Now create a CNN architecture with multiple filter sizes and richer feature extraction** #

# %%
# Number of words should match input dimensions
num_words = 15000

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Concatenate

input_layer = Input(shape=(maxlen,))
embedding = Embedding(input_dim=15000, output_dim=128)(input_layer)

branch_ksize3 = Conv1D(filters=128, kernel_size=3, activation='relu')(embedding)
branch_ksize3 = GlobalMaxPooling1D()(branch_ksize3)

branch_ksize4 = Conv1D(filters=128, kernel_size=4, activation='relu')(embedding)
branch_ksize4 = GlobalMaxPooling1D()(branch_ksize4)

branch_ksize5 = Conv1D(filters=128, kernel_size=5, activation='relu')(embedding)
branch_ksize5 = GlobalMaxPooling1D()(branch_ksize5)

merged_branches = Concatenate()([branch_ksize3, branch_ksize4, branch_ksize5])
merged_branches = Dropout(0.27)(merged_branches)
merged_branches = Dense(128, activation='relu')(merged_branches)
output = Dense(num_classes, activation='softmax')(merged_branches)

cnn_model3 = Model(inputs=input_layer, outputs=output)

# Compile
cnn_model3.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0004),
    metrics=['accuracy']
)

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model
history3 = cnn_model3.fit(
    x_train, y_train_cnn,
    epochs=100,
    batch_size=128,
    validation_split=0.2,
    class_weight=class_weightings,
    callbacks=[early_stop]
)

test_loss, test_acc = cnn_model3.evaluate(x_test, y_test_cnn)
print(f"Test Accuracy: {test_acc:.4f}")

y_pred_cnn3 = cnn_model3.predict(x_test)
y_pred_cnn3 = y_pred_cnn3.argmax(axis=1)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 9s 91ms/step - accuracy: 0.3790 - loss: 2.8617 - val_accuracy: 0.4914 - val_loss: 2.0315
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.5024 - loss: 2.1952 - val_accuracy: 0.5070 - val_loss: 1.8651
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.5645 - loss: 1.9796 - val_accuracy: 0.6416 - val_loss: 1.5966
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.6703 - loss: 1.7118 - val_accuracy: 0.6861 - val_loss: 1.3776
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7024 - loss: 1.5234 - val_accuracy: 0.7129 - val_loss: 1.2668
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7372 - loss: 1.3638 - val_accuracy: 0.7295 - val_loss: 1.1667
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7596 - loss: 1.2294 - val_accuracy: 0.7462 - val_loss: 1.0983
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7834 - loss: 1.1133 - val_accuracy: 0.7585 - val_loss: 1.0392
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8050 - loss: 0.9926 - val_accuracy: 0.7763 - val_loss: 0.9930
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8217 - loss: 0.8846 - val_accuracy: 0.7791 - val_loss: 0.9562
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8434 - loss: 0.7851 - val_accuracy: 0.7830 - val_loss: 0.9270
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8626 - loss: 0.6894 - val_accuracy: 0.7896 - val_loss: 0.8977
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8807 - loss: 0.6109 - val_accuracy: 0.8024 - val_loss: 0.8780
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8965 - loss: 0.5248 - val_accuracy: 0.8069 - val_loss: 0.8708
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9123 - loss: 0.4557 - val_accuracy: 0.8008 - val_loss: 0.8759
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9240 - loss: 0.3862 - val_accuracy: 0.8097 - val_loss: 0.8660
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9361 - loss: 0.3391 - val_accuracy: 0.8058 - val_loss: 0.8742
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9420 - loss: 0.2914 - val_accuracy: 0.8097 - val_loss: 0.8803
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9460 - loss: 0.2569 - val_accuracy: 0.8058 - val_loss: 0.8786
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8028 - loss: 0.8964
# Test Accuracy: 0.8028
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %%
# plot training curves
plt.figure(figsize=(10, 4))

#accuracy
plt.subplot(1, 2, 1)
plt.plot(history3.history['accuracy'], label='Train Accuracy')
plt.plot(history3.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

#loss
plt.subplot(1, 2, 2)
plt.plot(history3.history['loss'], label='Train Loss')
plt.plot(history3.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Phase 4: Using tuned CNN with GLoVe, allowing the model to focus on classification instead of also needing to learn word interpretations from scratch** #

# %%
#num_words and maxlen already defined during SVM training

tokenizer = Tokenizer(num_words=num_words, oov_token="<UNK>") #<UNK> is a 'catch-all'
tokenizer.fit_on_texts(X_train_text) # build an internal vocabulary

# Make sequences for train and test sets
X_train_seq = tokenizer.texts_to_sequences(X_train_text)
X_test_seq = tokenizer.texts_to_sequences(X_test_text)

# pad them so each entry is the same length
X_train_pad = pad_sequences(X_train_seq, maxlen=maxlen)
X_test_pad = pad_sequences(X_test_seq, maxlen=maxlen)

# %% [markdown]
# ***Gensim allows loading of the GLoVe vector file through an API instead of needing to download it***

# %%
# Needed if Gensim module not installed
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 57.1 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import gensim.downloader as api
word_vectors = api.load("glove-wiki-gigaword-100")
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %% [markdown]
# ***Build the GloVe embedding matrix***

# %%
embedding_dim = 100
embedding_matrix = {}

vocab_size = min(num_words, len(tokenizer.word_index) + 1)
embedding_matrix = np.zeros((vocab_size, embedding_dim))

for word, i in tokenizer.word_index.items():
    if i >= vocab_size:
        continue
    if word in word_vectors:
      embedding_vector = word_vectors[word]
    else:
      embedding_vector = None
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# ***Build the CNN model using the GLoVe file in the Embedding layer***

# %%
input_layer = Input(shape=(maxlen,)) #define the input

# Apply the embedding layer
embedding = Embedding(
    input_dim=vocab_size,
    output_dim=embedding_dim,
    weights=[embedding_matrix],
    trainable=False
)

# Set up embedding layer as a Tensor, as needed for the CNN branches
embedding_GLoVe = embedding(input_layer)

branch_ksize3 = Conv1D(filters=128, kernel_size=3, activation='relu')(embedding_GLoVe)
branch_ksize3 = GlobalMaxPooling1D()(branch_ksize3)

branch_ksize4 = Conv1D(filters=128, kernel_size=4, activation='relu')(embedding_GLoVe)
branch_ksize4 = GlobalMaxPooling1D()(branch_ksize4)

branch_ksize5 = Conv1D(filters=128, kernel_size=5, activation='relu')(embedding_GLoVe)
branch_ksize5 = GlobalMaxPooling1D()(branch_ksize5)

merged_branches = Concatenate()([branch_ksize3, branch_ksize4, branch_ksize5])
merged_branches = Dropout(0.27)(merged_branches)
merged_branches = Dense(128, activation='relu')(merged_branches)
output = Dense(num_classes, activation='softmax')(merged_branches)

cnn_model4 = Model(inputs=input_layer, outputs=output)

# Compile
cnn_model4.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0004),
    metrics=['accuracy']
)

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model
history4 = cnn_model4.fit(
    x_train, y_train_cnn,
    epochs=100,
    batch_size=128,
    validation_split=0.2,
    class_weight=class_weightings,
    callbacks=[early_stop]
)

test_loss, test_acc = cnn_model4.evaluate(x_test, y_test_cnn)
print(f"Test Accuracy: {test_acc:.4f}")

y_pred_cnn4 = cnn_model4.predict(x_test)
y_pred_cnn4 = y_pred_cnn4.argmax(axis=1)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 9s 86ms/step - accuracy: 0.3706 - loss: 2.7913 - val_accuracy: 0.4786 - val_loss: 2.0920
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4732 - loss: 2.3361 - val_accuracy: 0.5125 - val_loss: 1.9495
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5125 - loss: 2.1444 - val_accuracy: 0.5582 - val_loss: 1.7870
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5496 - loss: 1.9984 - val_accuracy: 0.5771 - val_loss: 1.7011
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5936 - loss: 1.8690 - val_accuracy: 0.6210 - val_loss: 1.6127
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6214 - loss: 1.7412 - val_accuracy: 0.6238 - val_loss: 1.5421
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6465 - loss: 1.6327 - val_accuracy: 0.6555 - val_loss: 1.4841
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6608 - loss: 1.5298 - val_accuracy: 0.6694 - val_loss: 1.4334
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6909 - loss: 1.4259 - val_accuracy: 0.6745 - val_loss: 1.3770
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7068 - loss: 1.3403 - val_accuracy: 0.6973 - val_loss: 1.3424
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7280 - loss: 1.2506 - val_accuracy: 0.6928 - val_loss: 1.3126
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7513 - loss: 1.1517 - val_accuracy: 0.6978 - val_loss: 1.2695
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7690 - loss: 1.0783 - val_accuracy: 0.7095 - val_loss: 1.2463
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7861 - loss: 0.9954 - val_accuracy: 0.7223 - val_loss: 1.2095
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8022 - loss: 0.9195 - val_accuracy: 0.7234 - val_loss: 1.1719
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8213 - loss: 0.8552 - val_accuracy: 0.7184 - val_loss: 1.1671
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8337 - loss: 0.7795 - val_accuracy: 0.7351 - val_loss: 1.1369
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8494 - loss: 0.7203 - val_accuracy: 0.7412 - val_loss: 1.1141
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8573 - loss: 0.6609 - val_accuracy: 0.7373 - val_loss: 1.1259
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8690 - loss: 0.6144 - val_accuracy: 0.7451 - val_loss: 1.1034
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8804 - loss: 0.5623 - val_accuracy: 0.7446 - val_loss: 1.0919
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8885 - loss: 0.5217 - val_accuracy: 0.7407 - val_loss: 1.0990
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8941 - loss: 0.4927 - val_accuracy: 0.7585 - val_loss: 1.0849
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9063 - loss: 0.4407 - val_accuracy: 0.7546 - val_loss: 1.0895
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9068 - loss: 0.4205 - val_accuracy: 0.7540 - val_loss: 1.0800
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9091 - loss: 0.4054 - val_accuracy: 0.7462 - val_loss: 1.0947
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9246 - loss: 0.3636 - val_accuracy: 0.7490 - val_loss: 1.0944
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9258 - loss: 0.3399 - val_accuracy: 0.7501 - val_loss: 1.0866
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7404 - loss: 1.0721
# Test Accuracy: 0.7404
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %% [markdown]
# ***Plot the results***

# %%
# plot training curves
plt.figure(figsize=(10, 4))

#accuracy
plt.subplot(1, 2, 1)
plt.plot(history4.history['accuracy'], label='Train Accuracy')
plt.plot(history4.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

#loss
plt.subplot(1, 2, 2)
plt.plot(history4.history['loss'], label='Train Loss')
plt.plot(history4.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Compare the results of the tuned SVM model and all CNN models** #

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
# Combine the results into a list
list_of_model_results = {
    "SVM": (y_test, y_pred_svm),
    "CNN_1": (y_test_cnn, y_pred_cnn),
    "CNN_2": (y_test_cnn, y_pred_cnn2),
    "CNN_3": (y_test_cnn, y_pred_cnn3),
    "CNN_4": (y_test_cnn, y_pred_cnn4)
}

# Tabulate the results
results_array = []

for name, (y_true, y_pred) in list_of_model_results.items():

    # Convert one-hot encoded true labels back to class labels if needed
    if len(y_true.shape) > 1:
        y_true_classes = np.argmax(y_true, axis=1)
    else:
        y_true_classes = y_true

    # Convert predicted probabilities back to class labels if needed
    if len(y_pred.shape) > 1:
        y_pred_classes = np.argmax(y_pred, axis=1)
    else:
        y_pred_classes = y_pred

    results_array.append({
        "Model": name,
        "Accuracy": accuracy_score(y_true_classes, y_pred_classes),
        "Precision": precision_score(y_true_classes, y_pred_classes, average='weighted', zero_division=0),
        "Recall": recall_score(y_true_classes, y_pred_classes, average='weighted', zero_division=0),
        "F1 Score": f1_score(y_true_classes, y_pred_classes, average='weighted', zero_division=0),
        "F1 Macro Score": f1_score(y_true_classes, y_pred_classes, average='macro', zero_division=0)
    })

df_results = pd.DataFrame(results_array)
print(df_results)
# Out:
#    Model  Accuracy  Precision    Recall  F1 Score  F1 Macro Score
# 0    SVM  0.830810   0.838305  0.830810  0.831235        0.695465
# 1  CNN_1  0.755565   0.745032  0.755565  0.742348        0.513119
# 2  CNN_2  0.669635   0.573712  0.669635  0.609163        0.094268
# 3  CNN_3  0.802760   0.799091  0.802760  0.795005        0.564767
# 4  CNN_4  0.740427   0.732888  0.740427  0.723729        0.449970

# %% [markdown]
# # **Provide class labels for further display** #

# %%
reuters_labels = [
    "cocoa",                # 0
    "grain",                # 1
    "veg-oil",              # 2
    "earn",                 # 3
    "acq",                  # 4
    "wheat",                # 5
    "copper",               # 6
    "housing",             # 7
    "money-supply",        # 8
    "coffee",              # 9
    "sugar",               # 10
    "trade",               # 11
    "reserves",            # 12
    "ship",                # 13
    "cotton",              # 14
    "carcass",             # 15
    "crude",               # 16
    "nat-gas",             # 17
    "cpi",                 # 18
    "money-fx",            # 19
    "interest",            # 20
    "gnp",                 # 21
    "meal-feed",           # 22
    "alum",                # 23
    "oilseed",             # 24
    "gold",                # 25
    "tin",                 # 26
    "strategic-metal",     # 27
    "livestock",           # 28
    "retail",              # 29
    "ipi",                 # 30
    "iron-steel",          # 31
    "rubber",              # 32
    "heat",                # 33
    "jobs",                # 34
    "lei",                 # 35
    "bop",                 # 36
    "zinc",                # 37
    "orange",              # 38
    "pet-chem",            # 39
    "dlr",                 # 40
    "gas",                 # 41
    "silver",              # 42
    "wpi",                 # 43
    "hog",                 # 44
    "lead"                 # 45
]

# %%
# Class labels
with open("label_encoder.pkl", "wb") as f:
    pickle.dump(reuters_labels, f)

# %% [markdown]
# # **Dump files** #

# %%
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (1.5.3)

# %%
# Class labels
joblib.dump(reuters_labels, f"{BASE_PATH}/reuter_class_labels.pkl")

# SVM
import joblib
joblib.dump(svm_model, f"{MODELS_PATH}/svm_model.pkl")
joblib.dump(vector, f"{MODELS_PATH}/tfidf_vectorizer.pkl")

# CNN
cnn_model.save(f"{MODELS_PATH}/cnn_model.keras")
joblib.dump(tokenizer, f"{MODELS_PATH}/tokenizer.pkl")
joblib.dump(maxlen, f"{MODELS_PATH}/maxlen.pkl")
# Out:
# ['/content/drive/MyDrive/reuters_text_classification/label_encoder.pkl']
